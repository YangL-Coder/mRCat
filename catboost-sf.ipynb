# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from catboost import CatBoostClassifier
from sklearn.metrics import roc_curve, auc
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_predict, GridSearchCV
from itertools import product
import random
from tqdm import tqdm

# %%
# training dataset loading
Training_csv_file_path = './data/TrainingSet/mRNA_sublocation_TrainingSet_DNABERT_data.csv'
Training_data= pd.read_csv(Training_csv_file_path)
Training_data
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.051352  0.110863  0.017913 -0.117001 -0.130711 -0.051733 -0.087305
# 1    -0.028948  0.076648  0.053617 -0.151656 -0.125982 -0.033365 -0.052527
# 2    -0.053768  0.076979  0.011430 -0.088812 -0.123918 -0.040801 -0.099212
# 3    -0.013776  0.108522  0.030686 -0.113928 -0.116355 -0.049274 -0.067821
# 4    -0.041918  0.088144  0.067097 -0.108955 -0.116393 -0.039382 -0.087630
# ...        ...       ...       ...       ...       ...       ...       ...
# 4657 -0.045684  0.073154  0.031592 -0.088793 -0.112148 -0.057297 -0.112139
# 4658 -0.051314  0.101583  0.049372 -0.130485 -0.146191 -0.078210 -0.049869
# 4659 -0.072383  0.114879  0.043321 -0.113051 -0.119378 -0.046503 -0.109755
# 4660 -0.077676  0.075969  0.107718 -0.085082 -0.079427 -0.056554 -0.071221
# 4661 -0.032444  0.054666  0.052779 -0.129823 -0.100632 -0.083809 -0.120683
#
#              7         8         9  ...       759       760       761  \
# 0    -0.113558  0.015367  0.044985  ... -0.047920 -0.044799  0.009836
# 1    -0.106612  0.023717  0.048803  ... -0.063734 -0.007245  0.007870
# 2    -0.122977  0.022925  0.024804  ... -0.080484 -0.063357  0.037052
# 3    -0.104782  0.024167  0.016909  ... -0.044457 -0.043053  0.013077
# 4    -0.126116  0.024942  0.020732  ... -0.056244 -0.031527  0.027563
# ...        ...       ...       ...  ...       ...       ...       ...
# 4657 -0.115460  0.027914  0.033002  ... -0.071451 -0.064951  0.026554
# 4658 -0.120071  0.025753  0.044124  ... -0.069669 -0.118523  0.001044
# 4659 -0.090195  0.016729  0.033405  ... -0.073933 -0.074885  0.044387
# 4660 -0.067641  0.003955  0.040569  ... -0.071051 -0.068419 -0.018095
# 4661 -0.017007 -0.001226  0.063492  ... -0.059454 -0.026457  0.048786
#
#            762       763       764       765       766       767  label
# 0    -0.027684 -0.060108  0.051503  0.074873  0.094912  0.142718      1
# 1    -0.022348 -0.066921  0.064694  0.101658  0.116233  0.136837      1
# 2    -0.023793 -0.052618  0.047666  0.088847  0.100192  0.156532      1
# 3    -0.001783 -0.055099  0.052132  0.093488  0.079941  0.162534      1
# 4    -0.006933 -0.035199  0.053570  0.106644  0.127546  0.129778      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 4657 -0.024152 -0.040399  0.054827  0.108673  0.107649  0.108352      0
# 4658 -0.004282 -0.044469  0.064367  0.085585  0.090057  0.146606      0
# 4659 -0.000744 -0.048722 -0.010145  0.098738  0.119175  0.117543      0
# 4660  0.009988 -0.081945  0.103257 -0.006743  0.098912  0.106491      0
# 4661  0.016240 -0.058569 -0.023089  0.105976  0.169302  0.109432      0
#
# [4662 rows x 769 columns]

# %%
# test dataset loading
Test_csv_file_path = './data/TestSet/mRNA_sublocation_TestSet_DNABERT_data.csv'
Test_data= pd.read_csv(Test_csv_file_path)
Test_data
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.029158  0.100403  0.067271 -0.116924 -0.109726 -0.056563 -0.095235
# 1   -0.051528  0.083082  0.069916 -0.125172 -0.106272 -0.032767 -0.076169
# 2   -0.042795  0.084680  0.087846 -0.136758 -0.113154 -0.070079 -0.075557
# 3   -0.011203  0.055997  0.090977 -0.172956 -0.144822 -0.070694 -0.123100
# 4   -0.023741  0.064950  0.127039 -0.152309 -0.082382 -0.070835 -0.145091
# ..        ...       ...       ...       ...       ...       ...       ...
# 513 -0.038825  0.066094  0.105642 -0.127595 -0.096262 -0.075581 -0.077916
# 514 -0.048585  0.073876  0.038217 -0.139759 -0.106150 -0.056394 -0.057778
# 515 -0.039191  0.074916  0.047489 -0.125525 -0.114935 -0.063233 -0.059096
# 516 -0.028589  0.071419  0.104370 -0.118703 -0.104961 -0.059899 -0.096033
# 517 -0.048280  0.068949  0.053442 -0.124389 -0.121108 -0.047943 -0.095837
#
#             7         8         9  ...       759       760       761  \
# 0   -0.063101  0.026661  0.055791  ... -0.053218 -0.046008  0.024874
# 1   -0.062987  0.034608  0.097928  ... -0.060201 -0.053725  0.023453
# 2   -0.065823  0.027558  0.086018  ... -0.086440 -0.074154  0.037891
# 3   -0.074747  0.023865  0.037438  ... -0.072469 -0.075094  0.079060
# 4   -0.057588  0.054729  0.018183  ... -0.060701 -0.105159  0.082175
# ..        ...       ...       ...  ...       ...       ...       ...
# 513 -0.082450  0.028816  0.078428  ... -0.083052 -0.081839  0.025406
# 514 -0.105467  0.015478  0.053942  ... -0.050953 -0.018395 -0.001208
# 515 -0.098679 -0.006991  0.081666  ... -0.077407 -0.028342  0.029947
# 516 -0.123387  0.024864  0.105596  ... -0.115380 -0.046133  0.049324
# 517 -0.112091 -0.003385  0.060680  ... -0.105616 -0.063114  0.069075
#
#           762       763       764       765       766       767  label
# 0   -0.005043 -0.057149  0.022523  0.123339  0.146821  0.165012      1
# 1    0.007158 -0.104437  0.018186  0.066489  0.168612  0.168197      1
# 2    0.010463 -0.048493  0.094847  0.098022  0.145162  0.164766      1
# 3   -0.053585 -0.033657 -0.002991  0.147035  0.143220  0.139921      1
# 4   -0.042828 -0.013750 -0.040331  0.205573  0.173816  0.187638      1
# ..        ...       ...       ...       ...       ...       ...    ...
# 513  0.034709 -0.057688  0.085145  0.059397  0.119146  0.114285      0
# 514 -0.011797 -0.064337  0.017005  0.087882  0.118566  0.137715      0
# 515 -0.024831 -0.072220 -0.001702  0.085262  0.091931  0.144309      0
# 516 -0.001430 -0.059596  0.059717  0.050933  0.101675  0.132865      0
# 517  0.015171 -0.053736  0.038425  0.062616  0.111214  0.115066      0
#
# [518 rows x 769 columns]

# %%
# separate sequence features and labels
X_train = Training_data.drop(columns=['label']).values
y_train = Training_data['label'].values

X_test = Test_data.drop(columns=['label']).values
y_test = Test_data['label'].values
# the training data and test data are standardized
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
# Random search was used, and the number of hyperparameters searched was defined
num = 100
# Define the hyperparameter search space
learning_rate = [0.08,0.1]
depth = [4, 5, 6]
rsm = [0.9, 1]
subsample = [0.6, 0.8, 1.0]
min_data_in_leaf = [140,150,160]

seed_value = 42
random.seed(seed_value)
# Hyperparameter tuning
hyperparameter_space = list(product(learning_rate,depth,rsm,subsample,min_data_in_leaf))
hyperparameters = [random.choice(hyperparameter_space) for i in range(num)]
results = []
best_acc = 0
for hyperparameter in tqdm(hyperparameters, desc="Hyperparameter Search"):
    learning_rate,depth,rsm,subsample,min_data_in_leaf = hyperparameter
    
    val_accuracy_scores = []
    val_precision_scores = []
    val_recall_scores = []
    val_f1_scores = []
    #     5-fold cross-validation
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for fold, (train_index, val_index) in enumerate(kf.split(X_train,y_train), 1):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        clf = CatBoostClassifier(iterations=1000,learning_rate=learning_rate,depth=depth,rsm=rsm,subsample=subsample,min_data_in_leaf=min_data_in_leaf, logging_level='Silent',early_stopping_rounds=50)
        
        clf.fit(X_train_fold,y_train_fold)
      
        val_predictions = clf.predict(X_val_fold)
        val_accuracy = accuracy_score(y_val_fold, val_predictions)
        val_precision = precision_score(y_val_fold, val_predictions)
        val_recall = recall_score(y_val_fold, val_predictions)
        val_f1 = f1_score(y_val_fold, val_predictions)
#         Saving metrics
        val_accuracy_scores.append(val_accuracy)
        val_precision_scores.append(val_precision)
        val_recall_scores.append(val_recall)
        val_f1_scores.append(val_f1)
#   The average value of each metric was calculated
    val_ACC = np.mean(val_accuracy_scores)
    val_Precision = np.mean(val_precision_scores)
    val_Recall = np.mean(val_recall_scores)
    val_F1 = np.mean(val_f1_scores)
    
# Independent testing
    clf.fit(X_train,y_train)
    test_predictions = clf.predict(X_test)
    cm = confusion_matrix(y_test,test_predictions)
    TP = cm[1, 1]
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]

    test_ACC = accuracy_score(y_test, test_predictions)
    test_Precision = precision_score(y_test, test_predictions)
    test_Recall = recall_score(y_test, test_predictions)
    test_F1 = f1_score(y_test, test_predictions)
    mcc = (TP * TN - FP * FN) / ((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))**0.5
    fpr, tpr, thresholds = roc_curve(y_test, test_predictions, pos_label=1)
    roc_auc = auc(fpr, tpr)
    
    
    results.append({
        "超参数组合": hyperparameter,
        "val_ACC": val_ACC,
        "val_Precision": val_Precision,
        "val_Recall": val_Recall,
        "val_F1":val_F1,
        "test_ACC":test_ACC,
        "test_Precision":test_Precision,
        "test_Recall":test_Recall,
        "test_F1":test_F1,
        "test_MCC":mcc,
        "test_roc_auc":roc_auc
    })
# Out:
# Hyperparameter Search: 100%|██████████████████████████████████████████████████████| 100/100 [4:33:41<00:00, 164.22s/it]

# %%
# result ranking
sorted_results = sorted(results, key=lambda x: x["test_ACC"], reverse=True)

for i,result in enumerate(sorted_results):
    print("超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count :", result["超参数组合"])
    print("val_ACC:", result["val_ACC"])
    print("val_Precision:", result["val_Precision"])
    print("val_Recall:", result["val_Recall"])
    print("val_F1:", result["val_F1"])
    print("test_ACC:", result["test_ACC"])
    print("test_Precision:", result["test_Precision"])
    print("test_Recall:", result["test_Recall"])
    print("test_F1:", result["test_F1"])
    print("test_MCC:", result["test_MCC"])
    print("test_roc_auc:", result["test_roc_auc"])
    print("-" * 60)
# Out:
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 0.9, 0.6, 140)
# val_ACC: 0.6894028676703974
# val_Precision: 0.6651169864829954
# val_Recall: 0.576400900079061
# val_F1: 0.6170929863297863
# test_ACC: 0.7239382239382239
# test_Precision: 0.7225130890052356
# test_Recall: 0.6052631578947368
# test_F1: 0.6587112171837708
# test_MCC: 0.43471761622115734
# test_roc_auc: 0.7112522686025408
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 0.9, 0.6, 140)
# val_ACC: 0.6894028676703974
# val_Precision: 0.6651169864829954
# val_Recall: 0.576400900079061
# val_F1: 0.6170929863297863
# test_ACC: 0.7239382239382239
# test_Precision: 0.7225130890052356
# test_Recall: 0.6052631578947368
# test_F1: 0.6587112171837708
# test_MCC: 0.43471761622115734
# test_roc_auc: 0.7112522686025408
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 0.6, 150)
# val_ACC: 0.6960501681317821
# val_Precision: 0.6781584112481945
# val_Recall: 0.5734488840235967
# val_F1: 0.6209916330422273
# test_ACC: 0.7200772200772201
# test_Precision: 0.7064676616915423
# test_Recall: 0.6228070175438597
# test_F1: 0.662004662004662
# test_MCC: 0.42719332990330466
# test_roc_auc: 0.7096793708408954
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.6936951731688354
# val_Precision: 0.673249522035775
# val_Recall: 0.5764118469865596
# val_F1: 0.620747481823338
# test_ACC: 0.7200772200772201
# test_Precision: 0.7150259067357513
# test_Recall: 0.6052631578947368
# test_F1: 0.6555819477434679
# test_MCC: 0.4267072000001246
# test_roc_auc: 0.7078039927404718
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.6936951731688354
# val_Precision: 0.673249522035775
# val_Recall: 0.5764118469865596
# val_F1: 0.620747481823338
# test_ACC: 0.7200772200772201
# test_Precision: 0.7150259067357513
# test_Recall: 0.6052631578947368
# test_F1: 0.6555819477434679
# test_MCC: 0.4267072000001246
# test_roc_auc: 0.7078039927404718
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 1, 1.0, 150)
# val_ACC: 0.6977701263633395
# val_Precision: 0.6809464845310137
# val_Recall: 0.5759253177643983
# val_F1: 0.6237301738724018
# test_ACC: 0.7200772200772201
# test_Precision: 0.7172774869109948
# test_Recall: 0.6008771929824561
# test_F1: 0.6539379474940334
# test_MCC: 0.42665691586310467
# test_roc_auc: 0.707335148215366
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 0.6, 140)
# val_ACC: 0.6960501681317821
# val_Precision: 0.6781584112481945
# val_Recall: 0.5734488840235967
# val_F1: 0.6209916330422273
# test_ACC: 0.7200772200772201
# test_Precision: 0.7064676616915423
# test_Recall: 0.6228070175438597
# test_F1: 0.662004662004662
# test_MCC: 0.42719332990330466
# test_roc_auc: 0.7096793708408954
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 1, 1.0, 150)
# val_ACC: 0.6977701263633395
# val_Precision: 0.6809464845310137
# val_Recall: 0.5759253177643983
# val_F1: 0.6237301738724018
# test_ACC: 0.7200772200772201
# test_Precision: 0.7172774869109948
# test_Recall: 0.6008771929824561
# test_F1: 0.6539379474940334
# test_MCC: 0.42665691586310467
# test_roc_auc: 0.707335148215366
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.6936951731688354
# val_Precision: 0.673249522035775
# val_Recall: 0.5764118469865596
# val_F1: 0.620747481823338
# test_ACC: 0.7200772200772201
# test_Precision: 0.7150259067357513
# test_Recall: 0.6052631578947368
# test_F1: 0.6555819477434679
# test_MCC: 0.4267072000001246
# test_roc_auc: 0.7078039927404718
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 1.0, 140)
# val_ACC: 0.6936951731688354
# val_Precision: 0.673249522035775
# val_Recall: 0.5764118469865596
# val_F1: 0.620747481823338
# test_ACC: 0.7200772200772201
# test_Precision: 0.7150259067357513
# test_Recall: 0.6052631578947368
# test_F1: 0.6555819477434679
# test_MCC: 0.4267072000001246
# test_roc_auc: 0.7078039927404718
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.694552622257796
# val_Precision: 0.676163660076802
# val_Recall: 0.5724697439639967
# val_F1: 0.6196479941425667
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.694552622257796
# val_Precision: 0.676163660076802
# val_Recall: 0.5724697439639967
# val_F1: 0.6196479941425667
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.694552622257796
# val_Precision: 0.676163660076802
# val_Recall: 0.5724697439639967
# val_F1: 0.6196479941425667
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.6, 150)
# val_ACC: 0.6883287562848166
# val_Precision: 0.6643425536024108
# val_Recall: 0.5734452350544305
# val_F1: 0.6151704333870629
# test_ACC: 0.7162162162162162
# test_Precision: 0.7076923076923077
# test_Recall: 0.6052631578947368
# test_F1: 0.6524822695035462
# test_MCC: 0.418759471407074
# test_roc_auc: 0.7043557168784028
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.6, 140)
# val_ACC: 0.6883287562848166
# val_Precision: 0.6643425536024108
# val_Recall: 0.5734452350544305
# val_F1: 0.6151704333870629
# test_ACC: 0.7162162162162162
# test_Precision: 0.7076923076923077
# test_Recall: 0.6052631578947368
# test_F1: 0.6524822695035462
# test_MCC: 0.418759471407074
# test_roc_auc: 0.7043557168784028
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6883287562848166
# val_Precision: 0.6643425536024108
# val_Recall: 0.5734452350544305
# val_F1: 0.6151704333870629
# test_ACC: 0.7162162162162162
# test_Precision: 0.7076923076923077
# test_Recall: 0.6052631578947368
# test_F1: 0.6524822695035462
# test_MCC: 0.418759471407074
# test_roc_auc: 0.7043557168784028
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.6, 150)
# val_ACC: 0.6883287562848166
# val_Precision: 0.6643425536024108
# val_Recall: 0.5734452350544305
# val_F1: 0.6151704333870629
# test_ACC: 0.7162162162162162
# test_Precision: 0.7076923076923077
# test_Recall: 0.6052631578947368
# test_F1: 0.6524822695035462
# test_MCC: 0.418759471407074
# test_roc_auc: 0.7043557168784028
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.6, 140)
# val_ACC: 0.6883287562848166
# val_Precision: 0.6643425536024108
# val_Recall: 0.5734452350544305
# val_F1: 0.6151704333870629
# test_ACC: 0.7162162162162162
# test_Precision: 0.7076923076923077
# test_Recall: 0.6052631578947368
# test_F1: 0.6524822695035462
# test_MCC: 0.418759471407074
# test_roc_auc: 0.7043557168784028
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6883287562848166
# val_Precision: 0.6643425536024108
# val_Recall: 0.5734452350544305
# val_F1: 0.6151704333870629
# test_ACC: 0.7162162162162162
# test_Precision: 0.7076923076923077
# test_Recall: 0.6052631578947368
# test_F1: 0.6524822695035462
# test_MCC: 0.418759471407074
# test_roc_auc: 0.7043557168784028
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6883287562848166
# val_Precision: 0.6643425536024108
# val_Recall: 0.5734452350544305
# val_F1: 0.6151704333870629
# test_ACC: 0.7162162162162162
# test_Precision: 0.7076923076923077
# test_Recall: 0.6052631578947368
# test_F1: 0.6524822695035462
# test_MCC: 0.418759471407074
# test_roc_auc: 0.7043557168784028
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 0.8, 150)
# val_ACC: 0.6960513181439723
# val_Precision: 0.6748647705825895
# val_Recall: 0.5813476859453871
# val_F1: 0.6244039665154573
# test_ACC: 0.7123552123552124
# test_Precision: 0.708994708994709
# test_Recall: 0.5877192982456141
# test_F1: 0.6426858513189448
# test_MCC: 0.41047868601773324
# test_roc_auc: 0.6990320629159104
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 1.0, 160)
# val_ACC: 0.6919747549324022
# val_Precision: 0.6709474941802809
# val_Recall: 0.5739366295688135
# val_F1: 0.6180659234163715
# test_ACC: 0.7104247104247104
# test_Precision: 0.696969696969697
# test_Recall: 0.6052631578947368
# test_F1: 0.6478873239436619
# test_MCC: 0.40695066629763366
# test_roc_auc: 0.6991833030852994
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 0.9, 1.0, 150)
# val_ACC: 0.6909043235858301
# val_Precision: 0.6686141957035018
# val_Recall: 0.5739524417685338
# val_F1: 0.6174843153922674
# test_ACC: 0.7104247104247104
# test_Precision: 0.7052631578947368
# test_Recall: 0.5877192982456141
# test_F1: 0.6411483253588517
# test_MCC: 0.40646880909824945
# test_roc_auc: 0.697307924984876
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 1.0, 140)
# val_ACC: 0.6919747549324022
# val_Precision: 0.6709474941802809
# val_Recall: 0.5739366295688135
# val_F1: 0.6180659234163715
# test_ACC: 0.7104247104247104
# test_Precision: 0.696969696969697
# test_Recall: 0.6052631578947368
# test_F1: 0.6478873239436619
# test_MCC: 0.40695066629763366
# test_roc_auc: 0.6991833030852994
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 0.9, 0.6, 150)
# val_ACC: 0.6928333540335527
# val_Precision: 0.6712794467437465
# val_Recall: 0.5764142796326703
# val_F1: 0.6199494166411632
# test_ACC: 0.7104247104247104
# test_Precision: 0.703125
# test_Recall: 0.5921052631578947
# test_F1: 0.6428571428571428
# test_MCC: 0.40654842467465896
# test_roc_auc: 0.6977767695099818
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 0.9, 1.0, 140)
# val_ACC: 0.6909043235858301
# val_Precision: 0.6686141957035018
# val_Recall: 0.5739524417685338
# val_F1: 0.6174843153922674
# test_ACC: 0.7104247104247104
# test_Precision: 0.7052631578947368
# test_Recall: 0.5877192982456141
# test_F1: 0.6411483253588517
# test_MCC: 0.40646880909824945
# test_roc_auc: 0.697307924984876
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 0.9, 0.6, 150)
# val_ACC: 0.6928333540335527
# val_Precision: 0.6712794467437465
# val_Recall: 0.5764142796326703
# val_F1: 0.6199494166411632
# test_ACC: 0.7104247104247104
# test_Precision: 0.703125
# test_Recall: 0.5921052631578947
# test_F1: 0.6428571428571428
# test_MCC: 0.40654842467465896
# test_roc_auc: 0.6977767695099818
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 0.9, 1.0, 160)
# val_ACC: 0.6909043235858301
# val_Precision: 0.6686141957035018
# val_Recall: 0.5739524417685338
# val_F1: 0.6174843153922674
# test_ACC: 0.7104247104247104
# test_Precision: 0.7052631578947368
# test_Recall: 0.5877192982456141
# test_F1: 0.6411483253588517
# test_MCC: 0.40646880909824945
# test_roc_auc: 0.697307924984876
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 0.8, 140)
# val_ACC: 0.6947653745129699
# val_Precision: 0.6729573538654258
# val_Recall: 0.5813476859453871
# val_F1: 0.6234822619815183
# test_ACC: 0.7084942084942085
# test_Precision: 0.6896551724137931
# test_Recall: 0.6140350877192983
# test_F1: 0.6496519721577726
# test_MCC: 0.4034854737710562
# test_roc_auc: 0.6983968542044768
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6947653745129699
# val_Precision: 0.6729573538654258
# val_Recall: 0.5813476859453871
# val_F1: 0.6234822619815183
# test_ACC: 0.7084942084942085
# test_Precision: 0.6896551724137931
# test_Recall: 0.6140350877192983
# test_F1: 0.6496519721577726
# test_MCC: 0.4034854737710562
# test_roc_auc: 0.6983968542044768
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 0.8, 140)
# val_ACC: 0.6947653745129699
# val_Precision: 0.6729573538654258
# val_Recall: 0.5813476859453871
# val_F1: 0.6234822619815183
# test_ACC: 0.7084942084942085
# test_Precision: 0.6896551724137931
# test_Recall: 0.6140350877192983
# test_F1: 0.6496519721577726
# test_MCC: 0.4034854737710562
# test_roc_auc: 0.6983968542044768
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6947653745129699
# val_Precision: 0.6729573538654258
# val_Recall: 0.5813476859453871
# val_F1: 0.6234822619815183
# test_ACC: 0.7084942084942085
# test_Precision: 0.6896551724137931
# test_Recall: 0.6140350877192983
# test_F1: 0.6496519721577726
# test_MCC: 0.4034854737710562
# test_roc_auc: 0.6983968542044768
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6947653745129699
# val_Precision: 0.6729573538654258
# val_Recall: 0.5813476859453871
# val_F1: 0.6234822619815183
# test_ACC: 0.7084942084942085
# test_Precision: 0.6896551724137931
# test_Recall: 0.6140350877192983
# test_F1: 0.6496519721577726
# test_MCC: 0.4034854737710562
# test_roc_auc: 0.6983968542044768
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 0.6, 150)
# val_ACC: 0.6894026376679593
# val_Precision: 0.6646451166505528
# val_Recall: 0.5778884631758195
# val_F1: 0.6178255004865194
# test_ACC: 0.7065637065637066
# test_Precision: 0.69
# test_Recall: 0.6052631578947368
# test_F1: 0.6448598130841122
# test_MCC: 0.3991502548317704
# test_roc_auc: 0.6957350272232304
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6941211376840595
# val_Precision: 0.6738749145284567
# val_Recall: 0.5754217600194612
# val_F1: 0.6205184838018394
# test_ACC: 0.7046332046332047
# test_Precision: 0.6903553299492385
# test_Recall: 0.5964912280701754
# test_F1: 0.6399999999999999
# test_MCC: 0.394850583396444
# test_roc_auc: 0.6930732002419844
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.6, 160)
# val_ACC: 0.6941211376840595
# val_Precision: 0.6738749145284567
# val_Recall: 0.5754217600194612
# val_F1: 0.6205184838018394
# test_ACC: 0.7046332046332047
# test_Precision: 0.6903553299492385
# test_Recall: 0.5964912280701754
# test_F1: 0.6399999999999999
# test_MCC: 0.394850583396444
# test_roc_auc: 0.6930732002419844
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 0.9, 1.0, 150)
# val_ACC: 0.6964800426884524
# val_Precision: 0.6810396116736769
# val_Recall: 0.5690275497172049
# val_F1: 0.6196421765638999
# test_ACC: 0.7046332046332047
# test_Precision: 0.7005347593582888
# test_Recall: 0.5745614035087719
# test_F1: 0.6313253012048192
# test_MCC: 0.39425598853404703
# test_roc_auc: 0.6907289776164549
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 0.9, 1.0, 150)
# val_ACC: 0.6964800426884524
# val_Precision: 0.6810396116736769
# val_Recall: 0.5690275497172049
# val_F1: 0.6196421765638999
# test_ACC: 0.7046332046332047
# test_Precision: 0.7005347593582888
# test_Recall: 0.5745614035087719
# test_F1: 0.6313253012048192
# test_MCC: 0.39425598853404703
# test_roc_auc: 0.6907289776164549
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6973361117627848
# val_Precision: 0.6820036784955777
# val_Recall: 0.5704980842911878
# val_F1: 0.620788461941179
# test_ACC: 0.7046332046332047
# test_Precision: 0.7027027027027027
# test_Recall: 0.5701754385964912
# test_F1: 0.6295399515738498
# test_MCC: 0.3942178030972468
# test_roc_auc: 0.690260133091349
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 0.9, 1.0, 160)
# val_ACC: 0.6964800426884524
# val_Precision: 0.6810396116736769
# val_Recall: 0.5690275497172049
# val_F1: 0.6196421765638999
# test_ACC: 0.7046332046332047
# test_Precision: 0.7005347593582888
# test_Recall: 0.5745614035087719
# test_F1: 0.6313253012048192
# test_MCC: 0.39425598853404703
# test_roc_auc: 0.6907289776164549
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6973361117627848
# val_Precision: 0.6820036784955777
# val_Recall: 0.5704980842911878
# val_F1: 0.620788461941179
# test_ACC: 0.7046332046332047
# test_Precision: 0.7027027027027027
# test_Recall: 0.5701754385964912
# test_F1: 0.6295399515738498
# test_MCC: 0.3942178030972468
# test_roc_auc: 0.690260133091349
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6973361117627848
# val_Precision: 0.6820036784955777
# val_Recall: 0.5704980842911878
# val_F1: 0.620788461941179
# test_ACC: 0.7046332046332047
# test_Precision: 0.7027027027027027
# test_Recall: 0.5701754385964912
# test_F1: 0.6295399515738498
# test_MCC: 0.3942178030972468
# test_roc_auc: 0.690260133091349
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6941211376840595
# val_Precision: 0.6738749145284567
# val_Recall: 0.5754217600194612
# val_F1: 0.6205184838018394
# test_ACC: 0.7046332046332047
# test_Precision: 0.6903553299492385
# test_Recall: 0.5964912280701754
# test_F1: 0.6399999999999999
# test_MCC: 0.394850583396444
# test_roc_auc: 0.6930732002419844
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.6, 150)
# val_ACC: 0.6941211376840595
# val_Precision: 0.6738749145284567
# val_Recall: 0.5754217600194612
# val_F1: 0.6205184838018394
# test_ACC: 0.7046332046332047
# test_Precision: 0.6903553299492385
# test_Recall: 0.5964912280701754
# test_F1: 0.6399999999999999
# test_MCC: 0.394850583396444
# test_roc_auc: 0.6930732002419844
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6941211376840595
# val_Precision: 0.6738749145284567
# val_Recall: 0.5754217600194612
# val_F1: 0.6205184838018394
# test_ACC: 0.7046332046332047
# test_Precision: 0.6903553299492385
# test_Recall: 0.5964912280701754
# test_F1: 0.6399999999999999
# test_MCC: 0.394850583396444
# test_roc_auc: 0.6930732002419844
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.69497973678521
# val_Precision: 0.6780990244893907
# val_Recall: 0.5695079973240893
# val_F1: 0.6186772986517586
# test_ACC: 0.7027027027027027
# test_Precision: 0.6968085106382979
# test_Recall: 0.5745614035087719
# test_F1: 0.6298076923076923
# test_MCC: 0.39024149655279683
# test_roc_auc: 0.6890048396854204
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.69497973678521
# val_Precision: 0.6780990244893907
# val_Recall: 0.5695079973240893
# val_F1: 0.6186772986517586
# test_ACC: 0.7027027027027027
# test_Precision: 0.6968085106382979
# test_Recall: 0.5745614035087719
# test_F1: 0.6298076923076923
# test_MCC: 0.39024149655279683
# test_roc_auc: 0.6890048396854204
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.69497973678521
# val_Precision: 0.6780990244893907
# val_Recall: 0.5695079973240893
# val_F1: 0.6186772986517586
# test_ACC: 0.7027027027027027
# test_Precision: 0.6968085106382979
# test_Recall: 0.5745614035087719
# test_F1: 0.6298076923076923
# test_MCC: 0.39024149655279683
# test_roc_auc: 0.6890048396854204
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 1, 0.6, 150)
# val_ACC: 0.6900466444944318
# val_Precision: 0.6680111459457294
# val_Recall: 0.5714930365505078
# val_F1: 0.6157468161575788
# test_ACC: 0.7027027027027027
# test_Precision: 0.6868686868686869
# test_Recall: 0.5964912280701754
# test_F1: 0.6384976525821596
# test_MCC: 0.3909445580863828
# test_roc_auc: 0.6913490623109498
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 0.8, 140)
# val_ACC: 0.69497973678521
# val_Precision: 0.6780990244893907
# val_Recall: 0.5695079973240893
# val_F1: 0.6186772986517586
# test_ACC: 0.7027027027027027
# test_Precision: 0.6968085106382979
# test_Recall: 0.5745614035087719
# test_F1: 0.6298076923076923
# test_MCC: 0.39024149655279683
# test_roc_auc: 0.6890048396854204
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.8, 160)
# val_ACC: 0.7001274213506663
# val_Precision: 0.6832388231137211
# val_Recall: 0.5798662044639056
# val_F1: 0.6268537818532889
# test_ACC: 0.7007722007722008
# test_Precision: 0.6834170854271356
# test_Recall: 0.5964912280701754
# test_F1: 0.6370023419203746
# test_MCC: 0.3870525731181626
# test_roc_auc: 0.6896249243799153
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 0.6, 140)
# val_ACC: 0.6949792767803339
# val_Precision: 0.6736086601200104
# val_Recall: 0.5808489934926715
# val_F1: 0.6234229522111502
# test_ACC: 0.7007722007722008
# test_Precision: 0.689119170984456
# test_Recall: 0.5833333333333334
# test_F1: 0.6318289786223278
# test_MCC: 0.386489891120928
# test_roc_auc: 0.6882183908045978
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.8, 140)
# val_ACC: 0.7001274213506663
# val_Precision: 0.6832388231137211
# val_Recall: 0.5798662044639056
# val_F1: 0.6268537818532889
# test_ACC: 0.7007722007722008
# test_Precision: 0.6834170854271356
# test_Recall: 0.5964912280701754
# test_F1: 0.6370023419203746
# test_MCC: 0.3870525731181626
# test_roc_auc: 0.6896249243799153
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 1, 0.8, 150)
# val_ACC: 0.7001274213506663
# val_Precision: 0.6832388231137211
# val_Recall: 0.5798662044639056
# val_F1: 0.6268537818532889
# test_ACC: 0.7007722007722008
# test_Precision: 0.6834170854271356
# test_Recall: 0.5964912280701754
# test_F1: 0.6370023419203746
# test_MCC: 0.3870525731181626
# test_roc_auc: 0.6896249243799153
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.6, 140)
# val_ACC: 0.6979794285819431
# val_Precision: 0.6799401564669831
# val_Recall: 0.5778860305297087
# val_F1: 0.6245086701811461
# test_ACC: 0.6988416988416989
# test_Precision: 0.6875
# test_Recall: 0.5789473684210527
# test_F1: 0.6285714285714286
# test_MCC: 0.3823924159591883
# test_roc_auc: 0.6860254083484574
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.6, 150)
# val_ACC: 0.6979794285819431
# val_Precision: 0.6799401564669831
# val_Recall: 0.5778860305297087
# val_F1: 0.6245086701811461
# test_ACC: 0.6988416988416989
# test_Precision: 0.6875
# test_Recall: 0.5789473684210527
# test_F1: 0.6285714285714286
# test_MCC: 0.3823924159591883
# test_roc_auc: 0.6860254083484574
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.6, 150)
# val_ACC: 0.6979794285819431
# val_Precision: 0.6799401564669831
# val_Recall: 0.5778860305297087
# val_F1: 0.6245086701811461
# test_ACC: 0.6988416988416989
# test_Precision: 0.6875
# test_Recall: 0.5789473684210527
# test_F1: 0.6285714285714286
# test_MCC: 0.3823924159591883
# test_roc_auc: 0.6860254083484574
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.6, 160)
# val_ACC: 0.6979794285819431
# val_Precision: 0.6799401564669831
# val_Recall: 0.5778860305297087
# val_F1: 0.6245086701811461
# test_ACC: 0.6988416988416989
# test_Precision: 0.6875
# test_Recall: 0.5789473684210527
# test_F1: 0.6285714285714286
# test_MCC: 0.3823924159591883
# test_roc_auc: 0.6860254083484574
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 0.6, 140)
# val_ACC: 0.6979794285819431
# val_Precision: 0.6799401564669831
# val_Recall: 0.5778860305297087
# val_F1: 0.6245086701811461
# test_ACC: 0.6988416988416989
# test_Precision: 0.6875
# test_Recall: 0.5789473684210527
# test_F1: 0.6285714285714286
# test_MCC: 0.3823924159591883
# test_roc_auc: 0.6860254083484574
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.8, 160)
# val_ACC: 0.6883322063213869
# val_Precision: 0.6680701275923134
# val_Recall: 0.5645745910113728
# val_F1: 0.6116090705871038
# test_ACC: 0.696911196911197
# test_Precision: 0.678391959798995
# test_Recall: 0.5921052631578947
# test_F1: 0.6323185011709602
# test_MCC: 0.3790571498897686
# test_roc_auc: 0.6857078039927405
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6894042476850254
# val_Precision: 0.66828592334392
# val_Recall: 0.5680313811348294
# val_F1: 0.613857850992501
# test_ACC: 0.696911196911197
# test_Precision: 0.6839378238341969
# test_Recall: 0.5789473684210527
# test_F1: 0.6270783847980999
# test_MCC: 0.37844642934508865
# test_roc_auc: 0.6843012704174228
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.8, 150)
# val_ACC: 0.6883322063213869
# val_Precision: 0.6680701275923134
# val_Recall: 0.5645745910113728
# val_F1: 0.6116090705871038
# test_ACC: 0.696911196911197
# test_Precision: 0.678391959798995
# test_Recall: 0.5921052631578947
# test_F1: 0.6323185011709602
# test_MCC: 0.3790571498897686
# test_roc_auc: 0.6857078039927405
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 0.8, 150)
# val_ACC: 0.6894042476850254
# val_Precision: 0.66828592334392
# val_Recall: 0.5680313811348294
# val_F1: 0.613857850992501
# test_ACC: 0.696911196911197
# test_Precision: 0.6839378238341969
# test_Recall: 0.5789473684210527
# test_F1: 0.6270783847980999
# test_MCC: 0.37844642934508865
# test_roc_auc: 0.6843012704174228
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6894042476850254
# val_Precision: 0.66828592334392
# val_Recall: 0.5680313811348294
# val_F1: 0.613857850992501
# test_ACC: 0.696911196911197
# test_Precision: 0.6839378238341969
# test_Recall: 0.5789473684210527
# test_F1: 0.6270783847980999
# test_MCC: 0.37844642934508865
# test_roc_auc: 0.6843012704174228
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6894042476850254
# val_Precision: 0.66828592334392
# val_Recall: 0.5680313811348294
# val_F1: 0.613857850992501
# test_ACC: 0.696911196911197
# test_Precision: 0.6839378238341969
# test_Recall: 0.5789473684210527
# test_F1: 0.6270783847980999
# test_MCC: 0.37844642934508865
# test_roc_auc: 0.6843012704174228
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 6, 1, 1.0, 160)
# val_ACC: 0.6958376458790463
# val_Precision: 0.677927044957068
# val_Recall: 0.5739475764763121
# val_F1: 0.6213475390575046
# test_ACC: 0.696911196911197
# test_Precision: 0.6858638743455497
# test_Recall: 0.5745614035087719
# test_F1: 0.6252983293556086
# test_MCC: 0.3782927137147886
# test_roc_auc: 0.683832425892317
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 0.9, 0.8, 140)
# val_ACC: 0.6919763649494686
# val_Precision: 0.6676175576967662
# val_Recall: 0.5813464696223317
# val_F1: 0.6213274715236594
# test_ACC: 0.696911196911197
# test_Precision: 0.6748768472906403
# test_Recall: 0.6008771929824561
# test_F1: 0.6357308584686775
# test_MCC: 0.3795863875444888
# test_roc_auc: 0.6866454930429522
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 0.9, 0.6, 160)
# val_ACC: 0.6881146240150146
# val_Precision: 0.6650919752989227
# val_Recall: 0.5709858298364046
# val_F1: 0.6140501189606946
# test_ACC: 0.696911196911197
# test_Precision: 0.6802030456852792
# test_Recall: 0.5877192982456141
# test_F1: 0.6305882352941177
# test_MCC: 0.37882891629638465
# test_roc_auc: 0.6852389594676347
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 0.9, 0.6, 150)
# val_ACC: 0.6881146240150146
# val_Precision: 0.6650919752989227
# val_Recall: 0.5709858298364046
# val_F1: 0.6140501189606946
# test_ACC: 0.696911196911197
# test_Precision: 0.6802030456852792
# test_Recall: 0.5877192982456141
# test_F1: 0.6305882352941177
# test_MCC: 0.37882891629638465
# test_roc_auc: 0.6852389594676347
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.8, 150)
# val_ACC: 0.6883322063213869
# val_Precision: 0.6680701275923134
# val_Recall: 0.5645745910113728
# val_F1: 0.6116090705871038
# test_ACC: 0.696911196911197
# test_Precision: 0.678391959798995
# test_Recall: 0.5921052631578947
# test_F1: 0.6323185011709602
# test_MCC: 0.3790571498897686
# test_roc_auc: 0.6857078039927405
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.8, 140)
# val_ACC: 0.6883322063213869
# val_Precision: 0.6680701275923134
# val_Recall: 0.5645745910113728
# val_F1: 0.6116090705871038
# test_ACC: 0.696911196911197
# test_Precision: 0.678391959798995
# test_Recall: 0.5921052631578947
# test_F1: 0.6323185011709602
# test_MCC: 0.3790571498897686
# test_roc_auc: 0.6857078039927405
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 0.8, 160)
# val_ACC: 0.6894042476850254
# val_Precision: 0.66828592334392
# val_Recall: 0.5680313811348294
# val_F1: 0.613857850992501
# test_ACC: 0.696911196911197
# test_Precision: 0.6839378238341969
# test_Recall: 0.5789473684210527
# test_F1: 0.6270783847980999
# test_MCC: 0.37844642934508865
# test_roc_auc: 0.6843012704174228
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 0.9, 0.8, 150)
# val_ACC: 0.6919763649494686
# val_Precision: 0.6676175576967662
# val_Recall: 0.5813464696223317
# val_F1: 0.6213274715236594
# test_ACC: 0.696911196911197
# test_Precision: 0.6748768472906403
# test_Recall: 0.6008771929824561
# test_F1: 0.6357308584686775
# test_MCC: 0.3795863875444888
# test_roc_auc: 0.6866454930429522
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 0.8, 160)
# val_ACC: 0.6894042476850254
# val_Precision: 0.66828592334392
# val_Recall: 0.5680313811348294
# val_F1: 0.613857850992501
# test_ACC: 0.696911196911197
# test_Precision: 0.6839378238341969
# test_Recall: 0.5789473684210527
# test_F1: 0.6270783847980999
# test_MCC: 0.37844642934508865
# test_roc_auc: 0.6843012704174228
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.8, 140)
# val_ACC: 0.6883322063213869
# val_Precision: 0.6680701275923134
# val_Recall: 0.5645745910113728
# val_F1: 0.6116090705871038
# test_ACC: 0.696911196911197
# test_Precision: 0.678391959798995
# test_Recall: 0.5921052631578947
# test_F1: 0.6323185011709602
# test_MCC: 0.3790571498897686
# test_roc_auc: 0.6857078039927405
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 0.9, 0.8, 150)
# val_ACC: 0.6919763649494686
# val_Precision: 0.6676175576967662
# val_Recall: 0.5813464696223317
# val_F1: 0.6213274715236594
# test_ACC: 0.696911196911197
# test_Precision: 0.6748768472906403
# test_Recall: 0.6008771929824561
# test_F1: 0.6357308584686775
# test_MCC: 0.3795863875444888
# test_roc_auc: 0.6866454930429522
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 0.9, 0.6, 160)
# val_ACC: 0.6881146240150146
# val_Precision: 0.6650919752989227
# val_Recall: 0.5709858298364046
# val_F1: 0.6140501189606946
# test_ACC: 0.696911196911197
# test_Precision: 0.6802030456852792
# test_Recall: 0.5877192982456141
# test_F1: 0.6305882352941177
# test_MCC: 0.37882891629638465
# test_roc_auc: 0.6852389594676347
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6902612367691097
# val_Precision: 0.6641696269831863
# val_Recall: 0.5833120476798638
# val_F1: 0.6207503955876291
# test_ACC: 0.694980694980695
# test_Precision: 0.6732673267326733
# test_Recall: 0.5964912280701754
# test_F1: 0.6325581395348837
# test_MCC: 0.3754583462121541
# test_roc_auc: 0.6844525105868118
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6902612367691097
# val_Precision: 0.6641696269831863
# val_Recall: 0.5833120476798638
# val_F1: 0.6207503955876291
# test_ACC: 0.694980694980695
# test_Precision: 0.6732673267326733
# test_Recall: 0.5964912280701754
# test_F1: 0.6325581395348837
# test_MCC: 0.3754583462121541
# test_roc_auc: 0.6844525105868118
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6902612367691097
# val_Precision: 0.6641696269831863
# val_Recall: 0.5833120476798638
# val_F1: 0.6207503955876291
# test_ACC: 0.694980694980695
# test_Precision: 0.6732673267326733
# test_Recall: 0.5964912280701754
# test_F1: 0.6325581395348837
# test_MCC: 0.3754583462121541
# test_roc_auc: 0.6844525105868118
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.6, 150)
# val_ACC: 0.6902612367691097
# val_Precision: 0.6641696269831863
# val_Recall: 0.5833120476798638
# val_F1: 0.6207503955876291
# test_ACC: 0.694980694980695
# test_Precision: 0.6732673267326733
# test_Recall: 0.5964912280701754
# test_F1: 0.6325581395348837
# test_MCC: 0.3754583462121541
# test_roc_auc: 0.6844525105868118
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.6, 150)
# val_ACC: 0.6902612367691097
# val_Precision: 0.6641696269831863
# val_Recall: 0.5833120476798638
# val_F1: 0.6207503955876291
# test_ACC: 0.694980694980695
# test_Precision: 0.6732673267326733
# test_Recall: 0.5964912280701754
# test_F1: 0.6325581395348837
# test_MCC: 0.3754583462121541
# test_roc_auc: 0.6844525105868118
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 1, 0.6, 140)
# val_ACC: 0.6902612367691097
# val_Precision: 0.6641696269831863
# val_Recall: 0.5833120476798638
# val_F1: 0.6207503955876291
# test_ACC: 0.694980694980695
# test_Precision: 0.6732673267326733
# test_Recall: 0.5964912280701754
# test_F1: 0.6325581395348837
# test_MCC: 0.3754583462121541
# test_roc_auc: 0.6844525105868118
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.701628877266099
# val_Precision: 0.6863566348522816
# val_Recall: 0.5788761174968072
# val_F1: 0.6277106434566366
# test_ACC: 0.693050193050193
# test_Precision: 0.6885245901639344
# test_Recall: 0.5526315789473685
# test_F1: 0.6131386861313869
# test_MCC: 0.3697991241821368
# test_roc_auc: 0.6780399274047187
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.701628877266099
# val_Precision: 0.6863566348522816
# val_Recall: 0.5788761174968072
# val_F1: 0.6277106434566366
# test_ACC: 0.693050193050193
# test_Precision: 0.6885245901639344
# test_Recall: 0.5526315789473685
# test_F1: 0.6131386861313869
# test_MCC: 0.3697991241821368
# test_roc_auc: 0.6780399274047187
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.701628877266099
# val_Precision: 0.6863566348522816
# val_Recall: 0.5788761174968072
# val_F1: 0.6277106434566366
# test_ACC: 0.693050193050193
# test_Precision: 0.6885245901639344
# test_Recall: 0.5526315789473685
# test_F1: 0.6131386861313869
# test_MCC: 0.3697991241821368
# test_roc_auc: 0.6780399274047187
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 1.0, 140)
# val_ACC: 0.701628877266099
# val_Precision: 0.6863566348522816
# val_Recall: 0.5788761174968072
# val_F1: 0.6277106434566366
# test_ACC: 0.693050193050193
# test_Precision: 0.6885245901639344
# test_Recall: 0.5526315789473685
# test_F1: 0.6131386861313869
# test_MCC: 0.3697991241821368
# test_roc_auc: 0.6780399274047187
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 1, 0.8, 160)
# val_ACC: 0.6840428908546431
# val_Precision: 0.6593900989889202
# val_Recall: 0.5660597214620202
# val_F1: 0.6089895939458653
# test_ACC: 0.693050193050193
# test_Precision: 0.6825396825396826
# test_Recall: 0.5657894736842105
# test_F1: 0.6187050359712231
# test_MCC: 0.3700858365957755
# test_roc_auc: 0.6794464609800364
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 1.0, 160)
# val_ACC: 0.6958376458790463
# val_Precision: 0.6770782031133329
# val_Recall: 0.5759253177643983
# val_F1: 0.6221042528272697
# test_ACC: 0.693050193050193
# test_Precision: 0.6787564766839378
# test_Recall: 0.5745614035087719
# test_F1: 0.6223277909738717
# test_MCC: 0.37040296756924934
# test_roc_auc: 0.680384150030248
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 5, 0.9, 1.0, 150)
# val_ACC: 0.6958376458790463
# val_Precision: 0.6770782031133329
# val_Recall: 0.5759253177643983
# val_F1: 0.6221042528272697
# test_ACC: 0.693050193050193
# test_Precision: 0.6787564766839378
# test_Recall: 0.5745614035087719
# test_F1: 0.6223277909738717
# test_MCC: 0.37040296756924934
# test_roc_auc: 0.680384150030248
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.701628877266099
# val_Precision: 0.6863566348522816
# val_Recall: 0.5788761174968072
# val_F1: 0.6277106434566366
# test_ACC: 0.693050193050193
# test_Precision: 0.6885245901639344
# test_Recall: 0.5526315789473685
# test_F1: 0.6131386861313869
# test_MCC: 0.3697991241821368
# test_roc_auc: 0.6780399274047187
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 5, 1, 1.0, 150)
# val_ACC: 0.701628877266099
# val_Precision: 0.6863566348522816
# val_Recall: 0.5788761174968072
# val_F1: 0.6277106434566366
# test_ACC: 0.693050193050193
# test_Precision: 0.6885245901639344
# test_Recall: 0.5526315789473685
# test_F1: 0.6131386861313869
# test_MCC: 0.3697991241821368
# test_roc_auc: 0.6780399274047187
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 1.0, 150)
# val_ACC: 0.6958341958424759
# val_Precision: 0.6792619489182317
# val_Recall: 0.5699884449309737
# val_F1: 0.6193579623492326
# test_ACC: 0.6911196911196911
# test_Precision: 0.6752577319587629
# test_Recall: 0.5745614035087719
# test_F1: 0.6208530805687204
# test_MCC: 0.3664801083010153
# test_roc_auc: 0.6786600120992136
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 1.0, 150)
# val_ACC: 0.6958341958424759
# val_Precision: 0.6792619489182317
# val_Recall: 0.5699884449309737
# val_F1: 0.6193579623492326
# test_ACC: 0.6911196911196911
# test_Precision: 0.6752577319587629
# test_Recall: 0.5745614035087719
# test_F1: 0.6208530805687204
# test_MCC: 0.3664801083010153
# test_roc_auc: 0.6786600120992136
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.08, 4, 0.9, 1.0, 160)
# val_ACC: 0.6893991876313889
# val_Precision: 0.6685313437260244
# val_Recall: 0.5665328711305724
# val_F1: 0.6129912629038203
# test_ACC: 0.6911196911196911
# test_Precision: 0.673469387755102
# test_Recall: 0.5789473684210527
# test_F1: 0.6226415094339622
# test_MCC: 0.36669585460143395
# test_roc_auc: 0.6791288566243194
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 6, 0.9, 1.0, 160)
# val_ACC: 0.6958341958424759
# val_Precision: 0.6792619489182317
# val_Recall: 0.5699884449309737
# val_F1: 0.6193579623492326
# test_ACC: 0.6911196911196911
# test_Precision: 0.6752577319587629
# test_Recall: 0.5745614035087719
# test_F1: 0.6208530805687204
# test_MCC: 0.3664801083010153
# test_roc_auc: 0.6786600120992136
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 1, 1.0, 140)
# val_ACC: 0.6891914954298516
# val_Precision: 0.6649319137574136
# val_Recall: 0.5764264428632245
# val_F1: 0.6173046276364266
# test_ACC: 0.6872586872586872
# test_Precision: 0.6666666666666666
# test_Recall: 0.5789473684210527
# test_F1: 0.619718309859155
# test_MCC: 0.358932341663881
# test_roc_auc: 0.6756805807622505
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 1, 1.0, 160)
# val_ACC: 0.6891914954298516
# val_Precision: 0.6649319137574136
# val_Recall: 0.5764264428632245
# val_F1: 0.6173046276364266
# test_ACC: 0.6872586872586872
# test_Precision: 0.6666666666666666
# test_Recall: 0.5789473684210527
# test_F1: 0.619718309859155
# test_MCC: 0.358932341663881
# test_roc_auc: 0.6756805807622505
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 1, 1.0, 140)
# val_ACC: 0.6891914954298516
# val_Precision: 0.6649319137574136
# val_Recall: 0.5764264428632245
# val_F1: 0.6173046276364266
# test_ACC: 0.6872586872586872
# test_Precision: 0.6666666666666666
# test_Recall: 0.5789473684210527
# test_F1: 0.619718309859155
# test_MCC: 0.358932341663881
# test_roc_auc: 0.6756805807622505
# ------------------------------------------------------------
# 超参数: iterations, learning_rate,depth,l2_leaf_reg,border_count : (0.1, 4, 1, 1.0, 150)
# val_ACC: 0.6891914954298516
# val_Precision: 0.6649319137574136
# val_Recall: 0.5764264428632245
# val_F1: 0.6173046276364266
# test_ACC: 0.6872586872586872
# test_Precision: 0.6666666666666666
# test_Recall: 0.5789473684210527
# test_F1: 0.619718309859155
# test_MCC: 0.358932341663881
# test_roc_auc: 0.6756805807622505
# ------------------------------------------------------------
