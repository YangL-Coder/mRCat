sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
# Random search was used, and the number of hyperparameters searched was defined
num = 50
# Define the hyperparameter search space
C = [0.1, 1, 10, 100, 1000]
gamma = [0.1, 0.01]
degree = [2, 3, 4]
coef0 = [-1, 0, 1]


# Hyperparameter tuning
hyperparameter_space = list(product(C, gamma,degree,coef0))
hyperparameters = [random.choice(hyperparameter_space) for i in range(num)]
results = []
best_acc = 0
for hyperparameter in tqdm(hyperparameters, desc="Hyperparameter Search"):
    C, gamma,degree,coef0 = hyperparameter
 
    val_accuracy_scores = []
    val_precision_scores = []
    val_recall_scores = []
    val_f1_scores = []
#     5-fold cross-validation    
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for fold, (train_index, val_index) in enumerate(kf.split(X_train,y_train), 1):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        clf = svm.SVC(kernel='rbf',C=C,gamma=gamma,degree=degree,coef0=coef0)
        
        clf.fit(X_train_fold,y_train_fold)
  
        val_predictions = clf.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, val_predictions)
        precision = precision_score(y_val_fold, val_predictions)
        recall = recall_score(y_val_fold, val_predictions)
        f1 = f1_score(y_val_fold, val_predictions)

#         Saving metrics      
        val_accuracy_scores.append(accuracy)
        val_precision_scores.append(precision)
        val_recall_scores.append(recall)
        val_f1_scores.append(f1)
#   The average value of each metric was calculated
    val_ACC = np.mean(val_accuracy_scores)
    val_Precision = np.mean(val_precision_scores)
    val_Recall = np.mean(val_recall_scores)
    val_F1 = np.mean(val_f1_scores)
    

 # Independent testing   
    clf.fit(X_train,y_train)
    test_predictions = clf.predict(X_test)
    cm = confusion_matrix(y_test,test_predictions)
    TP = cm[1, 1]
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
# Calculating test metrics
    test_ACC = accuracy_score(y_test, test_predictions)
    test_Precision = precision_score(y_test, test_predictions)
    test_Recall = recall_score(y_test, test_predictions)
    test_F1 = f1_score(y_test, test_predictions)
    mcc = (TP * TN - FP * FN) / ((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))**0.5
    fpr, tpr, thresholds = roc_curve(y_test, test_predictions, pos_label=1)
    roc_auc = auc(fpr, tpr)
    
   

    results.append({
        "超参数组合": hyperparameter,
        "val_ACC": val_ACC,
        "val_Precision": val_Precision,
        "val_Recall": val_Recall,
        "val_F1":val_F1,
        "test_ACC":test_ACC,      
        "test_Precision":test_Precision,
        "test_Recall":test_Recall,
        "test_F1":test_F1,
        "test_MCC":mcc,
        "test_roc_auc":roc_auc
    })
# Out:
# Hyperparameter Search: 100%|███████████████████████████████████████████████████████████| 50/50 [38:26<00:00, 46.13s/it]

# %%
# result ranking
sorted_results = sorted(results, key=lambda x: x["test_ACC"], reverse=True)
for i,result in enumerate(sorted_results):
    print("超参数: C, gamma,degree,coef0 :", result["超参数组合"])
    print("val_ACC:", result["val_ACC"])
    print("val_Precision:", result["val_Precision"])
    print("val_Recall:", result["val_Recall"])
    print("val_F1:", result["val_F1"])
    print("test_ACC:", result["test_ACC"])
    print("test_Precision:", result["test_Precision"])
    print("test_Recall:", result["test_Recall"])
    print("test_F1:", result["test_F1"])
    print("test_MCC:", result["test_MCC"])
    print("test_roc_auc:", result["test_roc_auc"])
    print("-" * 60)
# Out:
# 超参数: C, gamma,degree,coef0 : (10, 0.01, 4, 0)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.01, 3, 1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.01, 2, 1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.01, 4, -1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.01, 4, 0)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.01, 3, -1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.01, 2, 0)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.01, 3, 0)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.01, 2, -1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.01, 2, 0)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.01, 2, 0)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.01, 2, 1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.01, 2, 1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.01, 2, -1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.01, 2, 1)
# val_ACC: 0.625480820096693
# val_Precision: 0.6862468162081548
# val_Recall: 0.2564106306635042
# val_F1: 0.37315732347433667
# test_ACC: 0.6525096525096525
# test_Precision: 0.7727272727272727
# test_Recall: 0.2982456140350877
# test_F1: 0.430379746835443
# test_MCC: 0.3030799556184651
# test_roc_auc: 0.6146400483968543
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.01, 4, 0)
# val_ACC: 0.6136862950747278
# val_Precision: 0.7201955910475578
# val_Recall: 0.18393602140728577
# val_F1: 0.29263836995887776
# test_ACC: 0.6447876447876448
# test_Precision: 0.8055555555555556
# test_Recall: 0.2543859649122807
# test_F1: 0.3866666666666667
# test_MCC: 0.2957549519076127
# test_roc_auc: 0.6030550514216577
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.01, 3, 1)
# val_ACC: 0.6136862950747278
# val_Precision: 0.7201955910475578
# val_Recall: 0.18393602140728577
# val_F1: 0.29263836995887776
# test_ACC: 0.6447876447876448
# test_Precision: 0.8055555555555556
# test_Recall: 0.2543859649122807
# test_F1: 0.3866666666666667
# test_MCC: 0.2957549519076127
# test_roc_auc: 0.6030550514216577
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.01, 3, -1)
# val_ACC: 0.6136862950747278
# val_Precision: 0.7201955910475578
# val_Recall: 0.18393602140728577
# val_F1: 0.29263836995887776
# test_ACC: 0.6447876447876448
# test_Precision: 0.8055555555555556
# test_Recall: 0.2543859649122807
# test_F1: 0.3866666666666667
# test_MCC: 0.2957549519076127
# test_roc_auc: 0.6030550514216577
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.01, 2, -1)
# val_ACC: 0.6136862950747278
# val_Precision: 0.7201955910475578
# val_Recall: 0.18393602140728577
# val_F1: 0.29263836995887776
# test_ACC: 0.6447876447876448
# test_Precision: 0.8055555555555556
# test_Recall: 0.2543859649122807
# test_F1: 0.3866666666666667
# test_MCC: 0.2957549519076127
# test_roc_auc: 0.6030550514216577
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.01, 2, -1)
# val_ACC: 0.6136862950747278
# val_Precision: 0.7201955910475578
# val_Recall: 0.18393602140728577
# val_F1: 0.29263836995887776
# test_ACC: 0.6447876447876448
# test_Precision: 0.8055555555555556
# test_Recall: 0.2543859649122807
# test_F1: 0.3866666666666667
# test_MCC: 0.2957549519076127
# test_roc_auc: 0.6030550514216577
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.1, 3, -1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.1, 3, -1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.1, 3, -1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.1, 4, 1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.1, 3, 1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.1, 2, -1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.1, 3, -1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.1, 4, 1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.1, 3, -1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.1, 2, 1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.1, 3, -1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.1, 2, 0)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.1, 3, -1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.1, 4, 1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.1, 3, 0)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.1, 4, -1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.01, 4, 0)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.1, 4, 1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.1, 4, 1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.1, 2, 1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1000, 0.1, 2, -1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.01, 3, 0)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.1, 3, 0)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.1, 3, 0)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.1, 3, 0)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.1, 3, 1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (100, 0.1, 4, 0)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (10, 0.1, 3, 1)
# val_ACC: 0.5654225834793849
# val_Precision: 0.4
# val_Recall: 0.0009864379979322509
# val_F1: 0.00196802265767783
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (1, 0.1, 4, -1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
# 超参数: C, gamma,degree,coef0 : (0.1, 0.01, 2, -1)
# val_ACC: 0.5649936289324667
# val_Precision: 0.0
# val_Recall: 0.0
# val_F1: 0.0
# test_ACC: 0.5598455598455598
# test_Precision: 0.0
# test_Recall: 0.0
# test_F1: 0.0
# test_MCC: nan
# test_roc_auc: 0.5
# ------------------------------------------------------------
