# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from catboost import CatBoostClassifier
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_predict, GridSearchCV
from itertools import product
import random
from tqdm import tqdm

# %%
# training dataset loading
Training_csv_file_path = './data/TrainingSet/mRNA_sublocation_TrainingSet_NC-BERTdata.csv'
Training_data= pd.read_csv(Training_csv_file_path)
Training_data
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.008038  0.005472  0.007248  0.007894  0.007398  0.004448  0.000894
# 1     0.006421  0.004846  0.007124  0.006833  0.007555  0.005529  0.002641
# 2     0.012833  0.005971  0.006511  0.007626  0.007715  0.005825  0.001119
# 3     0.013917  0.006805  0.005778  0.013393  0.008006  0.004290  0.000706
# 4     0.017324  0.006722  0.007164  0.007420  0.007784  0.003431  0.001093
# ...        ...       ...       ...       ...       ...       ...       ...
# 4657  0.020823  0.006709  0.006760  0.009948  0.007638  0.003582  0.001047
# 4658  0.002121  0.007038  0.006064  0.003244  0.007038  0.005526  0.002388
# 4659  0.018389  0.005796  0.007591  0.005788  0.005100  0.006153  0.002046
# 4660  0.001512  0.001544  0.005322  0.000000  0.003088  0.007880  0.001362
# 4661  0.006508  0.003946  0.005190  0.002074  0.002492  0.006784  0.002657
#
#              7         8         9  ...       759       760       761  \
# 0     0.007232  0.009605  0.007154  ... -0.047920 -0.044799  0.009836
# 1     0.006684  0.008229  0.006792  ... -0.063734 -0.007245  0.007870
# 2     0.006599  0.007285  0.005525  ... -0.080484 -0.063357  0.037052
# 3     0.007448  0.006812  0.002914  ... -0.044457 -0.043053  0.013077
# 4     0.007214  0.006707  0.006244  ... -0.056244 -0.031527  0.027563
# ...        ...       ...       ...  ...       ...       ...       ...
# 4657  0.007103  0.007427  0.004873  ... -0.071451 -0.064951  0.026554
# 4658  0.005519  0.008397  0.006210  ... -0.069669 -0.118523  0.001044
# 4659  0.007090  0.005993  0.006751  ... -0.073933 -0.074885  0.044387
# 4660  0.001574  0.003991  0.010899  ... -0.071051 -0.068419 -0.018095
# 4661  0.002541  0.005190  0.005315  ... -0.059454 -0.026457  0.048786
#
#            762       763       764       765       766       767  label
# 0    -0.027684 -0.060108  0.051503  0.074873  0.094912  0.142718      1
# 1    -0.022348 -0.066921  0.064694  0.101658  0.116233  0.136837      1
# 2    -0.023793 -0.052618  0.047666  0.088847  0.100192  0.156532      1
# 3    -0.001783 -0.055099  0.052132  0.093488  0.079941  0.162534      1
# 4    -0.006933 -0.035199  0.053570  0.106644  0.127546  0.129778      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 4657 -0.024152 -0.040399  0.054827  0.108673  0.107649  0.108352      0
# 4658 -0.004282 -0.044469  0.064367  0.085585  0.090057  0.146606      0
# 4659 -0.000744 -0.048722 -0.010145  0.098738  0.119175  0.117543      0
# 4660  0.009988 -0.081945  0.103257 -0.006743  0.098912  0.106491      0
# 4661  0.016240 -0.058569 -0.023089  0.105976  0.169302  0.109432      0
#
# [4662 rows x 840 columns]

# %%
# test dataset loading
Test_csv_file_path = './data/TestSet/mRNA_sublocation_TestSet_NC-BERTdata.csv'
Test_data= pd.read_csv(Test_csv_file_path)
Test_data
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.011010  0.005166  0.007069  0.009104  0.006584  0.004962  0.000983
# 1    0.001138  0.002840  0.004449  0.000387  0.005293  0.008433  0.003076
# 2    0.003841  0.003923  0.006374  0.003134  0.005604  0.007207  0.001879
# 3    0.004768  0.003772  0.005141  0.003835  0.004800  0.007349  0.002178
# 4    0.014964  0.005276  0.007248  0.011185  0.005625  0.003709  0.000834
# ..        ...       ...       ...       ...       ...       ...       ...
# 513  0.002883  0.003271  0.005074  0.002614  0.003925  0.005676  0.004618
# 514  0.008520  0.004350  0.004851  0.005622  0.003838  0.005746  0.001919
# 515  0.003307  0.003241  0.005121  0.002833  0.005537  0.005652  0.001430
# 516  0.004880  0.002683  0.006275  0.003445  0.004216  0.005869  0.002368
# 517  0.003484  0.002668  0.004598  0.004885  0.006671  0.004085  0.005101
#
#             7         8         9  ...       759       760       761  \
# 0    0.006195  0.007331  0.005005  ... -0.053218 -0.046008  0.024874
# 1    0.004343  0.004783  0.009227  ... -0.060201 -0.053725  0.023453
# 2    0.005027  0.005505  0.008505  ... -0.086440 -0.074154  0.037891
# 3    0.004614  0.005968  0.006595  ... -0.072469 -0.075094  0.079060
# 4    0.006393  0.007677  0.003865  ... -0.060701 -0.105159  0.082175
# ..        ...       ...       ...  ...       ...       ...       ...
# 513  0.003668  0.004228  0.007505  ... -0.083052 -0.081839  0.025406
# 514  0.007434  0.004079  0.004629  ... -0.050953 -0.018395 -0.001208
# 515  0.006058  0.006633  0.008223  ... -0.077407 -0.028342  0.029947
# 516  0.002345  0.005615  0.008456  ... -0.115380 -0.046133  0.049324
# 517  0.003627  0.008430  0.006278  ... -0.105616 -0.063114  0.069075
#
#           762       763       764       765       766       767  label
# 0   -0.005043 -0.057149  0.022523  0.123339  0.146821  0.165012      1
# 1    0.007158 -0.104437  0.018186  0.066489  0.168612  0.168197      1
# 2    0.010463 -0.048493  0.094847  0.098022  0.145162  0.164766      1
# 3   -0.053585 -0.033657 -0.002991  0.147035  0.143220  0.139921      1
# 4   -0.042828 -0.013750 -0.040331  0.205573  0.173816  0.187638      1
# ..        ...       ...       ...       ...       ...       ...    ...
# 513  0.034709 -0.057688  0.085145  0.059397  0.119146  0.114285      0
# 514 -0.011797 -0.064337  0.017005  0.087882  0.118566  0.137715      0
# 515 -0.024831 -0.072220 -0.001702  0.085262  0.091931  0.144309      0
# 516 -0.001430 -0.059596  0.059717  0.050933  0.101675  0.132865      0
# 517  0.015171 -0.053736  0.038425  0.062616  0.111214  0.115066      0
#
# [518 rows x 840 columns]

# %%
# separate sequence features and labels
X_train = Training_data.drop(columns=['label']).values
y_train = Training_data['label'].values
X_test = Test_data.drop(columns=['label']).values
y_test = Test_data['label'].values
# the training data and test data are standardized
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.decomposition import PCA
import numpy as np
# Initialize PCA and set the number of principal components
pca = PCA(n_components=72)
# Fit PCA on the training data and transform the training data to its principal components
X_train = pca.fit_transform(X_train)
# Get the transformation matrix (principal components)
transformation_matrix = pca.components_
# Apply the same transformation matrix to the test data
# This ensures the test data is transformed in the same way as the training data
X_test = np.dot(X_test, transformation_matrix.T)

# %%
# Random search was used, and the number of hyperparameters searched was defined
num = 100 
# Define the hyperparameter search space
learning_rate = [0.08,0.1]
depth = [4, 5, 6]
rsm = [0.9, 1]
subsample = [0.6, 0.8, 1.0]
min_data_in_leaf = [140,150,160]

seed_value = 42
random.seed(seed_value)
# Hyperparameter tuning
hyperparameter_space = list(product(learning_rate,depth,rsm,subsample,min_data_in_leaf))
hyperparameters = [random.choice(hyperparameter_space) for i in range(num)]
results = []
best_acc = 0
for hyperparameter in tqdm(hyperparameters, desc="Hyperparameter Search"):
    learning_rate,depth,rsm,subsample,min_data_in_leaf = hyperparameter
    val_accuracy_scores = []
    val_precision_scores = []
    val_recall_scores = []
    val_f1_scores = []
    
#     5-fold cross-validation
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for fold, (train_index, val_index) in enumerate(kf.split(X_train,y_train), 1):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        clf = CatBoostClassifier(iterations=1000,learning_rate=learning_rate,depth=depth,rsm=rsm,subsample=subsample,min_data_in_leaf=min_data_in_leaf, logging_level='Silent',early_stopping_rounds=50)
        
        clf.fit(X_train_fold,y_train_fold)
        val_predictions = clf.predict(X_val_fold)
        val_accuracy = accuracy_score(y_val_fold, val_predictions)
        val_precision = precision_score(y_val_fold, val_predictions)
        val_recall = recall_score(y_val_fold, val_predictions)
        val_f1 = f1_score(y_val_fold, val_predictions)

#         Saving metrics
        val_accuracy_scores.append(val_accuracy)
        val_precision_scores.append(val_precision)
        val_recall_scores.append(val_recall)
        val_f1_scores.append(val_f1)
#   The average value of each metric was calculated
    val_ACC = np.mean(val_accuracy_scores)
    val_Precision = np.mean(val_precision_scores)
    val_Recall = np.mean(val_recall_scores)
    val_F1 = np.mean(val_f1_scores)
    
# Independent testing
    clf.fit(X_train,y_train)
    test_predictions = clf.predict(X_test)
    cm = confusion_matrix(y_test,test_predictions)
    TP = cm[1, 1]
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
# Calculating test metrics
    test_ACC = accuracy_score(y_test, test_predictions)
    test_Precision = precision_score(y_test, test_predictions)
    test_Recall = recall_score(y_test, test_predictions)
    test_F1 = f1_score(y_test, test_predictions)
    mcc = (TP * TN - FP * FN) / ((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))**0.5
    fpr, tpr, thresholds = roc_curve(y_test, test_predictions, pos_label=1)
    roc_auc = auc(fpr, tpr)
    results.append({
        "超参数组合": hyperparameter,
        "val_ACC": val_ACC,
        "val_Precision": val_Precision,
        "val_Recall": val_Recall,
        "val_F1":val_F1,
        "test_ACC":test_ACC,      
        "test_Precision":test_Precision,
        "test_Recall":test_Recall,
        "test_F1":test_F1,
        "test_MCC":mcc,
        "test_roc_auc":roc_auc
    })

# %%
# result ranking
sorted_results = sorted(results, key=lambda x: x["test_ACC"], reverse=True)
for i,result in enumerate(sorted_results):
    print("超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf:", result["超参数组合"])
    print("val_ACC:", result["val_ACC"])
    print("val_Precision:", result["val_Precision"])
    print("val_Recall:", result["val_Recall"])
    print("val_F1:", result["val_F1"])
    print("test_ACC:", result["test_ACC"])
    print("test_Precision:", result["test_Precision"])
    print("test_Recall:", result["test_Recall"])
    print("test_F1:", result["test_F1"])
    print("test_MCC:", result["test_MCC"])
    print("test_roc_auc:", result["test_roc_auc"])
    print("-" * 60)
# Out:
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 0.9, 0.6, 150)
# val_ACC: 0.6911189158605081
# val_Precision: 0.6691544568475355
# val_Recall: 0.5739378458918689
# val_F1: 0.6173392854959217
# test_ACC: 0.7606177606177607
# test_Precision: 0.76
# test_Recall: 0.6666666666666666
# test_F1: 0.7102803738317756
# test_MCC: 0.510981411068828
# test_roc_auc: 0.7505747126436781
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 0.9, 0.6, 150)
# val_ACC: 0.6911189158605081
# val_Precision: 0.6691544568475355
# val_Recall: 0.5739378458918689
# val_F1: 0.6173392854959217
# test_ACC: 0.7606177606177607
# test_Precision: 0.76
# test_Recall: 0.6666666666666666
# test_F1: 0.7102803738317756
# test_MCC: 0.510981411068828
# test_roc_auc: 0.7505747126436781
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 0.8, 140)
# val_ACC: 0.6896172299426374
# val_Precision: 0.6668417141216527
# val_Recall: 0.5734452350544305
# val_F1: 0.6162355599052238
# test_ACC: 0.752895752895753
# test_Precision: 0.7450980392156863
# test_Recall: 0.6666666666666666
# test_F1: 0.7037037037037038
# test_MCC: 0.49514582178813454
# test_roc_auc: 0.7436781609195401
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6896172299426374
# val_Precision: 0.6668417141216527
# val_Recall: 0.5734452350544305
# val_F1: 0.6162355599052238
# test_ACC: 0.752895752895753
# test_Precision: 0.7450980392156863
# test_Recall: 0.6666666666666666
# test_F1: 0.7037037037037038
# test_MCC: 0.49514582178813454
# test_roc_auc: 0.7436781609195401
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 0.8, 140)
# val_ACC: 0.6896172299426374
# val_Precision: 0.6668417141216527
# val_Recall: 0.5734452350544305
# val_F1: 0.6162355599052238
# test_ACC: 0.752895752895753
# test_Precision: 0.7450980392156863
# test_Recall: 0.6666666666666666
# test_F1: 0.7037037037037038
# test_MCC: 0.49514582178813454
# test_roc_auc: 0.7436781609195401
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6896172299426374
# val_Precision: 0.6668417141216527
# val_Recall: 0.5734452350544305
# val_F1: 0.6162355599052238
# test_ACC: 0.752895752895753
# test_Precision: 0.7450980392156863
# test_Recall: 0.6666666666666666
# test_F1: 0.7037037037037038
# test_MCC: 0.49514582178813454
# test_roc_auc: 0.7436781609195401
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6896172299426374
# val_Precision: 0.6668417141216527
# val_Recall: 0.5734452350544305
# val_F1: 0.6162355599052238
# test_ACC: 0.752895752895753
# test_Precision: 0.7450980392156863
# test_Recall: 0.6666666666666666
# test_F1: 0.7037037037037038
# test_MCC: 0.49514582178813454
# test_roc_auc: 0.7436781609195401
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 0.9, 1.0, 150)
# val_ACC: 0.6857582490374399
# val_Precision: 0.6597529058536833
# val_Recall: 0.5739487927993675
# val_F1: 0.6136759462952878
# test_ACC: 0.750965250965251
# test_Precision: 0.7538461538461538
# test_Recall: 0.6447368421052632
# test_F1: 0.6950354609929077
# test_MCC: 0.4910010587257455
# test_roc_auc: 0.7396098003629764
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 0.6, 140)
# val_ACC: 0.6853249244441992
# val_Precision: 0.6589706948577637
# val_Recall: 0.5729538405400475
# val_F1: 0.6127955503042213
# test_ACC: 0.750965250965251
# test_Precision: 0.746268656716418
# test_Recall: 0.6578947368421053
# test_F1: 0.6993006993006994
# test_MCC: 0.4910381495484033
# test_roc_auc: 0.741016333938294
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 0.9, 1.0, 140)
# val_ACC: 0.6857582490374399
# val_Precision: 0.6597529058536833
# val_Recall: 0.5739487927993675
# val_F1: 0.6136759462952878
# test_ACC: 0.750965250965251
# test_Precision: 0.7538461538461538
# test_Recall: 0.6447368421052632
# test_F1: 0.6950354609929077
# test_MCC: 0.4910010587257455
# test_roc_auc: 0.7396098003629764
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 0.9, 1.0, 160)
# val_ACC: 0.6857582490374399
# val_Precision: 0.6597529058536833
# val_Recall: 0.5739487927993675
# val_F1: 0.6136759462952878
# test_ACC: 0.750965250965251
# test_Precision: 0.7538461538461538
# test_Recall: 0.6447368421052632
# test_F1: 0.6950354609929077
# test_MCC: 0.4910010587257455
# test_roc_auc: 0.7396098003629764
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6930516263472393
# val_Precision: 0.668716665923945
# val_Recall: 0.5847959618074561
# val_F1: 0.6235619171849789
# test_ACC: 0.7413127413127413
# test_Precision: 0.7397959183673469
# test_Recall: 0.6359649122807017
# test_F1: 0.6839622641509434
# test_MCC: 0.47093977071448934
# test_roc_auc: 0.7300514216575922
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 0.8, 150)
# val_ACC: 0.6930516263472393
# val_Precision: 0.668716665923945
# val_Recall: 0.5847959618074561
# val_F1: 0.6235619171849789
# test_ACC: 0.7413127413127413
# test_Precision: 0.7397959183673469
# test_Recall: 0.6359649122807017
# test_F1: 0.6839622641509434
# test_MCC: 0.47093977071448934
# test_roc_auc: 0.7300514216575922
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6930516263472393
# val_Precision: 0.668716665923945
# val_Recall: 0.5847959618074561
# val_F1: 0.6235619171849789
# test_ACC: 0.7413127413127413
# test_Precision: 0.7397959183673469
# test_Recall: 0.6359649122807017
# test_F1: 0.6839622641509434
# test_MCC: 0.47093977071448934
# test_roc_auc: 0.7300514216575922
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6930516263472393
# val_Precision: 0.668716665923945
# val_Recall: 0.5847959618074561
# val_F1: 0.6235619171849789
# test_ACC: 0.7413127413127413
# test_Precision: 0.7397959183673469
# test_Recall: 0.6359649122807017
# test_F1: 0.6839622641509434
# test_MCC: 0.47093977071448934
# test_roc_auc: 0.7300514216575922
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 0.8, 160)
# val_ACC: 0.6930516263472393
# val_Precision: 0.668716665923945
# val_Recall: 0.5847959618074561
# val_F1: 0.6235619171849789
# test_ACC: 0.7413127413127413
# test_Precision: 0.7397959183673469
# test_Recall: 0.6359649122807017
# test_F1: 0.6839622641509434
# test_MCC: 0.47093977071448934
# test_roc_auc: 0.7300514216575922
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 0.8, 160)
# val_ACC: 0.6930516263472393
# val_Precision: 0.668716665923945
# val_Recall: 0.5847959618074561
# val_F1: 0.6235619171849789
# test_ACC: 0.7413127413127413
# test_Precision: 0.7397959183673469
# test_Recall: 0.6359649122807017
# test_F1: 0.6839622641509434
# test_MCC: 0.47093977071448934
# test_roc_auc: 0.7300514216575922
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 1.0, 160)
# val_ACC: 0.6900475645041837
# val_Precision: 0.6630596229127884
# val_Recall: 0.5847910965152344
# val_F1: 0.6212999172293622
# test_ACC: 0.7374517374517374
# test_Precision: 0.7277227722772277
# test_Recall: 0.6447368421052632
# test_F1: 0.6837209302325582
# test_MCC: 0.46316585919661024
# test_roc_auc: 0.727540834845735
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 0.9, 0.6, 160)
# val_ACC: 0.6898338922392577
# val_Precision: 0.6670535450073295
# val_Recall: 0.5739475764763121
# val_F1: 0.6166964607285411
# test_ACC: 0.7374517374517374
# test_Precision: 0.7277227722772277
# test_Recall: 0.6447368421052632
# test_F1: 0.6837209302325582
# test_MCC: 0.46316585919661024
# test_roc_auc: 0.727540834845735
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 0.9, 0.6, 150)
# val_ACC: 0.6898338922392577
# val_Precision: 0.6670535450073295
# val_Recall: 0.5739475764763121
# val_F1: 0.6166964607285411
# test_ACC: 0.7374517374517374
# test_Precision: 0.7277227722772277
# test_Recall: 0.6447368421052632
# test_F1: 0.6837209302325582
# test_MCC: 0.46316585919661024
# test_roc_auc: 0.727540834845735
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 1.0, 140)
# val_ACC: 0.6900475645041837
# val_Precision: 0.6630596229127884
# val_Recall: 0.5847910965152344
# val_F1: 0.6212999172293622
# test_ACC: 0.7374517374517374
# test_Precision: 0.7277227722772277
# test_Recall: 0.6447368421052632
# test_F1: 0.6837209302325582
# test_MCC: 0.46316585919661024
# test_roc_auc: 0.727540834845735
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 0.9, 0.6, 160)
# val_ACC: 0.6898338922392577
# val_Precision: 0.6670535450073295
# val_Recall: 0.5739475764763121
# val_F1: 0.6166964607285411
# test_ACC: 0.7374517374517374
# test_Precision: 0.7277227722772277
# test_Recall: 0.6447368421052632
# test_F1: 0.6837209302325582
# test_MCC: 0.46316585919661024
# test_roc_auc: 0.727540834845735
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6952000791208387
# val_Precision: 0.6761730784347537
# val_Recall: 0.5754363558961261
# val_F1: 0.6215443008363354
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6952000791208387
# val_Precision: 0.6761730784347537
# val_Recall: 0.5754363558961261
# val_F1: 0.6215443008363354
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6952000791208387
# val_Precision: 0.6761730784347537
# val_Recall: 0.5754363558961261
# val_F1: 0.6215443008363354
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.6870471827001365
# val_Precision: 0.6659812786322161
# val_Recall: 0.5640868454661558
# val_F1: 0.6105334605269614
# test_ACC: 0.7335907335907336
# test_Precision: 0.7295918367346939
# test_Recall: 0.6271929824561403
# test_F1: 0.6745283018867925
# test_MCC: 0.45490224515863464
# test_roc_auc: 0.7222171808832426
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.6, 150)
# val_ACC: 0.6915497104269305
# val_Precision: 0.6688884826493121
# val_Recall: 0.5773934196922703
# val_F1: 0.6193153935326748
# test_ACC: 0.7335907335907336
# test_Precision: 0.7184466019417476
# test_Recall: 0.6491228070175439
# test_F1: 0.6820276497695854
# test_MCC: 0.455533819215688
# test_roc_auc: 0.724561403508772
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.6870471827001365
# val_Precision: 0.6659812786322161
# val_Recall: 0.5640868454661558
# val_F1: 0.6105334605269614
# test_ACC: 0.7335907335907336
# test_Precision: 0.7295918367346939
# test_Recall: 0.6271929824561403
# test_F1: 0.6745283018867925
# test_MCC: 0.45490224515863464
# test_roc_auc: 0.7222171808832426
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.6870471827001365
# val_Precision: 0.6659812786322161
# val_Recall: 0.5640868454661558
# val_F1: 0.6105334605269614
# test_ACC: 0.7335907335907336
# test_Precision: 0.7295918367346939
# test_Recall: 0.6271929824561403
# test_F1: 0.6745283018867925
# test_MCC: 0.45490224515863464
# test_roc_auc: 0.7222171808832426
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6859756013413743
# val_Precision: 0.6584510107924052
# val_Recall: 0.5783895882746457
# val_F1: 0.6155914669954289
# test_ACC: 0.7335907335907336
# test_Precision: 0.7272727272727273
# test_Recall: 0.631578947368421
# test_F1: 0.676056338028169
# test_MCC: 0.4549689909313864
# test_roc_auc: 0.7226860254083485
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6859756013413743
# val_Precision: 0.6584510107924052
# val_Recall: 0.5783895882746457
# val_F1: 0.6155914669954289
# test_ACC: 0.7335907335907336
# test_Precision: 0.7272727272727273
# test_Recall: 0.631578947368421
# test_F1: 0.676056338028169
# test_MCC: 0.4549689909313864
# test_roc_auc: 0.7226860254083485
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.6, 140)
# val_ACC: 0.6915497104269305
# val_Precision: 0.6688884826493121
# val_Recall: 0.5773934196922703
# val_F1: 0.6193153935326748
# test_ACC: 0.7335907335907336
# test_Precision: 0.7184466019417476
# test_Recall: 0.6491228070175439
# test_F1: 0.6820276497695854
# test_MCC: 0.455533819215688
# test_roc_auc: 0.724561403508772
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6915497104269305
# val_Precision: 0.6688884826493121
# val_Recall: 0.5773934196922703
# val_F1: 0.6193153935326748
# test_ACC: 0.7335907335907336
# test_Precision: 0.7184466019417476
# test_Recall: 0.6491228070175439
# test_F1: 0.6820276497695854
# test_MCC: 0.455533819215688
# test_roc_auc: 0.724561403508772
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.6, 150)
# val_ACC: 0.6915497104269305
# val_Precision: 0.6688884826493121
# val_Recall: 0.5773934196922703
# val_F1: 0.6193153935326748
# test_ACC: 0.7335907335907336
# test_Precision: 0.7184466019417476
# test_Recall: 0.6491228070175439
# test_F1: 0.6820276497695854
# test_MCC: 0.455533819215688
# test_roc_auc: 0.724561403508772
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 1.0, 150)
# val_ACC: 0.6861901936160524
# val_Precision: 0.6652466280027098
# val_Recall: 0.5616335218634069
# val_F1: 0.6089235722984626
# test_ACC: 0.7335907335907336
# test_Precision: 0.7295918367346939
# test_Recall: 0.6271929824561403
# test_F1: 0.6745283018867925
# test_MCC: 0.45490224515863464
# test_roc_auc: 0.7222171808832426
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.6, 140)
# val_ACC: 0.6915497104269305
# val_Precision: 0.6688884826493121
# val_Recall: 0.5773934196922703
# val_F1: 0.6193153935326748
# test_ACC: 0.7335907335907336
# test_Precision: 0.7184466019417476
# test_Recall: 0.6491228070175439
# test_F1: 0.6820276497695854
# test_MCC: 0.455533819215688
# test_roc_auc: 0.724561403508772
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 1.0, 150)
# val_ACC: 0.6861901936160524
# val_Precision: 0.6652466280027098
# val_Recall: 0.5616335218634069
# val_F1: 0.6089235722984626
# test_ACC: 0.7335907335907336
# test_Precision: 0.7295918367346939
# test_Recall: 0.6271929824561403
# test_F1: 0.6745283018867925
# test_MCC: 0.45490224515863464
# test_roc_auc: 0.7222171808832426
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6859756013413743
# val_Precision: 0.6584510107924052
# val_Recall: 0.5783895882746457
# val_F1: 0.6155914669954289
# test_ACC: 0.7335907335907336
# test_Precision: 0.7272727272727273
# test_Recall: 0.631578947368421
# test_F1: 0.676056338028169
# test_MCC: 0.4549689909313864
# test_roc_auc: 0.7226860254083485
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 0.8, 140)
# val_ACC: 0.6870471827001365
# val_Precision: 0.6659812786322161
# val_Recall: 0.5640868454661558
# val_F1: 0.6105334605269614
# test_ACC: 0.7335907335907336
# test_Precision: 0.7295918367346939
# test_Recall: 0.6271929824561403
# test_F1: 0.6745283018867925
# test_MCC: 0.45490224515863464
# test_roc_auc: 0.7222171808832426
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.6, 150)
# val_ACC: 0.6859756013413743
# val_Precision: 0.6584510107924052
# val_Recall: 0.5783895882746457
# val_F1: 0.6155914669954289
# test_ACC: 0.7335907335907336
# test_Precision: 0.7272727272727273
# test_Recall: 0.631578947368421
# test_F1: 0.676056338028169
# test_MCC: 0.4549689909313864
# test_roc_auc: 0.7226860254083485
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6915497104269305
# val_Precision: 0.6688884826493121
# val_Recall: 0.5773934196922703
# val_F1: 0.6193153935326748
# test_ACC: 0.7335907335907336
# test_Precision: 0.7184466019417476
# test_Recall: 0.6491228070175439
# test_F1: 0.6820276497695854
# test_MCC: 0.455533819215688
# test_roc_auc: 0.724561403508772
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 1.0, 160)
# val_ACC: 0.6861901936160524
# val_Precision: 0.6652466280027098
# val_Recall: 0.5616335218634069
# val_F1: 0.6089235722984626
# test_ACC: 0.7335907335907336
# test_Precision: 0.7295918367346939
# test_Recall: 0.6271929824561403
# test_F1: 0.6745283018867925
# test_MCC: 0.45490224515863464
# test_roc_auc: 0.7222171808832426
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.6, 150)
# val_ACC: 0.6859756013413743
# val_Precision: 0.6584510107924052
# val_Recall: 0.5783895882746457
# val_F1: 0.6155914669954289
# test_ACC: 0.7335907335907336
# test_Precision: 0.7272727272727273
# test_Recall: 0.631578947368421
# test_F1: 0.676056338028169
# test_MCC: 0.4549689909313864
# test_roc_auc: 0.7226860254083485
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6915497104269305
# val_Precision: 0.6688884826493121
# val_Recall: 0.5773934196922703
# val_F1: 0.6193153935326748
# test_ACC: 0.7335907335907336
# test_Precision: 0.7184466019417476
# test_Recall: 0.6491228070175439
# test_F1: 0.6820276497695854
# test_MCC: 0.455533819215688
# test_roc_auc: 0.724561403508772
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.6, 140)
# val_ACC: 0.6859756013413743
# val_Precision: 0.6584510107924052
# val_Recall: 0.5783895882746457
# val_F1: 0.6155914669954289
# test_ACC: 0.7335907335907336
# test_Precision: 0.7272727272727273
# test_Recall: 0.631578947368421
# test_F1: 0.676056338028169
# test_MCC: 0.4549689909313864
# test_roc_auc: 0.7226860254083485
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.690263996798366
# val_Precision: 0.6652851017736287
# val_Recall: 0.5808477771696163
# val_F1: 0.6199112723396647
# test_ACC: 0.7297297297297297
# test_Precision: 0.72
# test_Recall: 0.631578947368421
# test_F1: 0.6728971962616822
# test_MCC: 0.4470778932190808
# test_roc_auc: 0.7192377495462796
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 0.9, 0.6, 140)
# val_ACC: 0.6876879694924766
# val_Precision: 0.6620582984481351
# val_Recall: 0.5754168947272396
# val_F1: 0.6153779826939981
# test_ACC: 0.7297297297297297
# test_Precision: 0.7244897959183674
# test_Recall: 0.6228070175438597
# test_F1: 0.669811320754717
# test_MCC: 0.4468834823807073
# test_roc_auc: 0.7183000604960678
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.684043580861957
# val_Precision: 0.6593657223168926
# val_Recall: 0.5685154777108801
# val_F1: 0.609986238502423
# test_ACC: 0.7297297297297297
# test_Precision: 0.7222222222222222
# test_Recall: 0.6271929824561403
# test_F1: 0.6713615023474178
# test_MCC: 0.4469659368257609
# test_roc_auc: 0.7187689050211736
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.690263996798366
# val_Precision: 0.6652851017736287
# val_Recall: 0.5808477771696163
# val_F1: 0.6199112723396647
# test_ACC: 0.7297297297297297
# test_Precision: 0.72
# test_Recall: 0.631578947368421
# test_F1: 0.6728971962616822
# test_MCC: 0.4470778932190808
# test_roc_auc: 0.7192377495462796
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.684043580861957
# val_Precision: 0.6593657223168926
# val_Recall: 0.5685154777108801
# val_F1: 0.609986238502423
# test_ACC: 0.7297297297297297
# test_Precision: 0.7222222222222222
# test_Recall: 0.6271929824561403
# test_F1: 0.6713615023474178
# test_MCC: 0.4469659368257609
# test_roc_auc: 0.7187689050211736
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 0.9, 0.6, 140)
# val_ACC: 0.6876879694924766
# val_Precision: 0.6620582984481351
# val_Recall: 0.5754168947272396
# val_F1: 0.6153779826939981
# test_ACC: 0.7297297297297297
# test_Precision: 0.7244897959183674
# test_Recall: 0.6228070175438597
# test_F1: 0.669811320754717
# test_MCC: 0.4468834823807073
# test_roc_auc: 0.7183000604960678
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.690263996798366
# val_Precision: 0.6652851017736287
# val_Recall: 0.5808477771696163
# val_F1: 0.6199112723396647
# test_ACC: 0.7297297297297297
# test_Precision: 0.72
# test_Recall: 0.631578947368421
# test_F1: 0.6728971962616822
# test_MCC: 0.4470778932190808
# test_roc_auc: 0.7192377495462796
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 1.0, 140)
# val_ACC: 0.690263996798366
# val_Precision: 0.6652851017736287
# val_Recall: 0.5808477771696163
# val_F1: 0.6199112723396647
# test_ACC: 0.7297297297297297
# test_Precision: 0.72
# test_Recall: 0.631578947368421
# test_F1: 0.6728971962616822
# test_MCC: 0.4470778932190808
# test_roc_auc: 0.7192377495462796
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 0.9, 1.0, 160)
# val_ACC: 0.6866170781410283
# val_Precision: 0.6596630402960516
# val_Recall: 0.5783920209207565
# val_F1: 0.6162268300806496
# test_ACC: 0.7297297297297297
# test_Precision: 0.7244897959183674
# test_Recall: 0.6228070175438597
# test_F1: 0.669811320754717
# test_MCC: 0.4468834823807073
# test_roc_auc: 0.7183000604960678
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.690263996798366
# val_Precision: 0.6652851017736287
# val_Recall: 0.5808477771696163
# val_F1: 0.6199112723396647
# test_ACC: 0.7297297297297297
# test_Precision: 0.72
# test_Recall: 0.631578947368421
# test_F1: 0.6728971962616822
# test_MCC: 0.4470778932190808
# test_roc_auc: 0.7192377495462796
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 1.0, 150)
# val_ACC: 0.690263996798366
# val_Precision: 0.6652851017736287
# val_Recall: 0.5808477771696163
# val_F1: 0.6199112723396647
# test_ACC: 0.7297297297297297
# test_Precision: 0.72
# test_Recall: 0.631578947368421
# test_F1: 0.6728971962616822
# test_MCC: 0.4470778932190808
# test_roc_auc: 0.7192377495462796
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.684043580861957
# val_Precision: 0.6593657223168926
# val_Recall: 0.5685154777108801
# val_F1: 0.609986238502423
# test_ACC: 0.7297297297297297
# test_Precision: 0.7222222222222222
# test_Recall: 0.6271929824561403
# test_F1: 0.6713615023474178
# test_MCC: 0.4469659368257609
# test_roc_auc: 0.7187689050211736
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 1.0, 140)
# val_ACC: 0.684043580861957
# val_Precision: 0.6593657223168926
# val_Recall: 0.5685154777108801
# val_F1: 0.609986238502423
# test_ACC: 0.7297297297297297
# test_Precision: 0.7222222222222222
# test_Recall: 0.6271929824561403
# test_F1: 0.6713615023474178
# test_MCC: 0.4469659368257609
# test_roc_auc: 0.7187689050211736
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6902626167837379
# val_Precision: 0.6658693493775388
# val_Recall: 0.5783822903363134
# val_F1: 0.6187693890017283
# test_ACC: 0.7277992277992278
# test_Precision: 0.7185929648241206
# test_Recall: 0.6271929824561403
# test_F1: 0.6697892271662763
# test_MCC: 0.4430205357169207
# test_roc_auc: 0.7170447670901392
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.8, 160)
# val_ACC: 0.6894051676947776
# val_Precision: 0.665656132098069
# val_Recall: 0.5763936021407285
# val_F1: 0.6170780881563068
# test_ACC: 0.7277992277992278
# test_Precision: 0.7253886010362695
# test_Recall: 0.6140350877192983
# test_F1: 0.665083135391924
# test_MCC: 0.44279412355180325
# test_roc_auc: 0.7156382335148216
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.6, 160)
# val_ACC: 0.6902626167837379
# val_Precision: 0.6658693493775388
# val_Recall: 0.5783822903363134
# val_F1: 0.6187693890017283
# test_ACC: 0.7277992277992278
# test_Precision: 0.7185929648241206
# test_Recall: 0.6271929824561403
# test_F1: 0.6697892271662763
# test_MCC: 0.4430205357169207
# test_roc_auc: 0.7170447670901392
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 1.0, 160)
# val_ACC: 0.6909043235858301
# val_Precision: 0.6689372827096431
# val_Recall: 0.572967220093657
# val_F1: 0.6170837611961366
# test_ACC: 0.7277992277992278
# test_Precision: 0.7208121827411168
# test_Recall: 0.6228070175438597
# test_F1: 0.668235294117647
# test_MCC: 0.4429155846966222
# test_roc_auc: 0.7165759225650331
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.8, 140)
# val_ACC: 0.6894051676947776
# val_Precision: 0.665656132098069
# val_Recall: 0.5763936021407285
# val_F1: 0.6170780881563068
# test_ACC: 0.7277992277992278
# test_Precision: 0.7253886010362695
# test_Recall: 0.6140350877192983
# test_F1: 0.665083135391924
# test_MCC: 0.44279412355180325
# test_roc_auc: 0.7156382335148216
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6902626167837379
# val_Precision: 0.6658693493775388
# val_Recall: 0.5783822903363134
# val_F1: 0.6187693890017283
# test_ACC: 0.7277992277992278
# test_Precision: 0.7185929648241206
# test_Recall: 0.6271929824561403
# test_F1: 0.6697892271662763
# test_MCC: 0.4430205357169207
# test_roc_auc: 0.7170447670901392
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.8, 150)
# val_ACC: 0.6894051676947776
# val_Precision: 0.665656132098069
# val_Recall: 0.5763936021407285
# val_F1: 0.6170780881563068
# test_ACC: 0.7277992277992278
# test_Precision: 0.7253886010362695
# test_Recall: 0.6140350877192983
# test_F1: 0.665083135391924
# test_MCC: 0.44279412355180325
# test_roc_auc: 0.7156382335148216
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.6, 150)
# val_ACC: 0.6902626167837379
# val_Precision: 0.6658693493775388
# val_Recall: 0.5783822903363134
# val_F1: 0.6187693890017283
# test_ACC: 0.7277992277992278
# test_Precision: 0.7185929648241206
# test_Recall: 0.6271929824561403
# test_F1: 0.6697892271662763
# test_MCC: 0.4430205357169207
# test_roc_auc: 0.7170447670901392
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6902626167837379
# val_Precision: 0.6658693493775388
# val_Recall: 0.5783822903363134
# val_F1: 0.6187693890017283
# test_ACC: 0.7277992277992278
# test_Precision: 0.7185929648241206
# test_Recall: 0.6271929824561403
# test_F1: 0.6697892271662763
# test_MCC: 0.4430205357169207
# test_roc_auc: 0.7170447670901392
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.8, 160)
# val_ACC: 0.6900482545114978
# val_Precision: 0.6645315471261044
# val_Recall: 0.5803563826552333
# val_F1: 0.6193830767001348
# test_ACC: 0.7258687258687259
# test_Precision: 0.7193877551020408
# test_Recall: 0.618421052631579
# test_F1: 0.6650943396226415
# test_MCC: 0.43886471960278
# test_roc_auc: 0.7143829401088929
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.8, 150)
# val_ACC: 0.6900482545114978
# val_Precision: 0.6645315471261044
# val_Recall: 0.5803563826552333
# val_F1: 0.6193830767001348
# test_ACC: 0.7258687258687259
# test_Precision: 0.7193877551020408
# test_Recall: 0.618421052631579
# test_F1: 0.6650943396226415
# test_MCC: 0.43886471960278
# test_roc_auc: 0.7143829401088929
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.8, 150)
# val_ACC: 0.6900482545114978
# val_Precision: 0.6645315471261044
# val_Recall: 0.5803563826552333
# val_F1: 0.6193830767001348
# test_ACC: 0.7258687258687259
# test_Precision: 0.7193877551020408
# test_Recall: 0.618421052631579
# test_F1: 0.6650943396226415
# test_MCC: 0.43886471960278
# test_roc_auc: 0.7143829401088929
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.8, 140)
# val_ACC: 0.6900482545114978
# val_Precision: 0.6645315471261044
# val_Recall: 0.5803563826552333
# val_F1: 0.6193830767001348
# test_ACC: 0.7258687258687259
# test_Precision: 0.7193877551020408
# test_Recall: 0.618421052631579
# test_F1: 0.6650943396226415
# test_MCC: 0.43886471960278
# test_roc_auc: 0.7143829401088929
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 0.6, 150)
# val_ACC: 0.6909068536126484
# val_Precision: 0.665754819732153
# val_Recall: 0.5828109225810375
# val_F1: 0.6208789387445742
# test_ACC: 0.7258687258687259
# test_Precision: 0.7263157894736842
# test_Recall: 0.6052631578947368
# test_F1: 0.6602870813397129
# test_MCC: 0.4387470312526099
# test_roc_auc: 0.7129764065335753
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 4, 1, 0.8, 140)
# val_ACC: 0.6900482545114978
# val_Precision: 0.6645315471261044
# val_Recall: 0.5803563826552333
# val_F1: 0.6193830767001348
# test_ACC: 0.7258687258687259
# test_Precision: 0.7193877551020408
# test_Recall: 0.618421052631579
# test_F1: 0.6650943396226415
# test_MCC: 0.43886471960278
# test_roc_auc: 0.7143829401088929
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 1, 1.0, 140)
# val_ACC: 0.6829703894861285
# val_Precision: 0.6547246202523506
# val_Recall: 0.5739475764763121
# val_F1: 0.6115229375017593
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 1, 1.0, 160)
# val_ACC: 0.6829703894861285
# val_Precision: 0.6547246202523506
# val_Recall: 0.5739475764763121
# val_F1: 0.6115229375017593
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 1, 1.0, 140)
# val_ACC: 0.6829703894861285
# val_Precision: 0.6547246202523506
# val_Recall: 0.5739475764763121
# val_F1: 0.6115229375017593
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.6915476404049883
# val_Precision: 0.6704360896195891
# val_Recall: 0.5719771331265584
# val_F1: 0.6171329831792922
# test_ACC: 0.7239382239382239
# test_Precision: 0.7135678391959799
# test_Recall: 0.6228070175438597
# test_F1: 0.6651053864168618
# test_MCC: 0.43502511248852666
# test_roc_auc: 0.7131276467029642
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.6915476404049883
# val_Precision: 0.6704360896195891
# val_Recall: 0.5719771331265584
# val_F1: 0.6171329831792922
# test_ACC: 0.7239382239382239
# test_Precision: 0.7135678391959799
# test_Recall: 0.6228070175438597
# test_F1: 0.6651053864168618
# test_MCC: 0.43502511248852666
# test_roc_auc: 0.7131276467029642
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.6915476404049883
# val_Precision: 0.6704360896195891
# val_Recall: 0.5719771331265584
# val_F1: 0.6171329831792922
# test_ACC: 0.7239382239382239
# test_Precision: 0.7135678391959799
# test_Recall: 0.6228070175438597
# test_F1: 0.6651053864168618
# test_MCC: 0.43502511248852666
# test_roc_auc: 0.7131276467029642
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 1, 1.0, 150)
# val_ACC: 0.6829703894861285
# val_Precision: 0.6547246202523506
# val_Recall: 0.5739475764763121
# val_F1: 0.6115229375017593
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 5, 1, 0.8, 150)
# val_ACC: 0.6864004158444079
# val_Precision: 0.6614396109573246
# val_Recall: 0.5719832147418356
# val_F1: 0.6132809713054129
# test_ACC: 0.722007722007722
# test_Precision: 0.7121212121212122
# test_Recall: 0.618421052631579
# test_F1: 0.6619718309859155
# test_MCC: 0.43095982861451
# test_roc_auc: 0.7109346642468239
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 0.9, 1.0, 150)
# val_ACC: 0.6956255836311865
# val_Precision: 0.6757795579784364
# val_Recall: 0.5774007176306027
# val_F1: 0.6225859407288018
# test_ACC: 0.722007722007722
# test_Precision: 0.71
# test_Recall: 0.6228070175438597
# test_F1: 0.663551401869159
# test_MCC: 0.431102013756644
# test_roc_auc: 0.7114035087719298
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 0.9, 1.0, 150)
# val_ACC: 0.6956255836311865
# val_Precision: 0.6757795579784364
# val_Recall: 0.5774007176306027
# val_F1: 0.6225859407288018
# test_ACC: 0.722007722007722
# test_Precision: 0.71
# test_Recall: 0.6228070175438597
# test_F1: 0.663551401869159
# test_MCC: 0.431102013756644
# test_roc_auc: 0.7114035087719298
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 0.9, 1.0, 160)
# val_ACC: 0.6956255836311865
# val_Precision: 0.6757795579784364
# val_Recall: 0.5774007176306027
# val_F1: 0.6225859407288018
# test_ACC: 0.722007722007722
# test_Precision: 0.71
# test_Recall: 0.6228070175438597
# test_F1: 0.663551401869159
# test_MCC: 0.431102013756644
# test_roc_auc: 0.7114035087719298
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 1.0, 160)
# val_ACC: 0.688118764058899
# val_Precision: 0.6637192355888664
# val_Recall: 0.573953658091589
# val_F1: 0.6154098015999592
# test_ACC: 0.722007722007722
# test_Precision: 0.7058823529411765
# test_Recall: 0.631578947368421
# test_F1: 0.6666666666666667
# test_MCC: 0.4314701674469593
# test_roc_auc: 0.7123411978221416
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 5, 0.9, 1.0, 150)
# val_ACC: 0.688118764058899
# val_Precision: 0.6637192355888664
# val_Recall: 0.573953658091589
# val_F1: 0.6154098015999592
# test_ACC: 0.722007722007722
# test_Precision: 0.7058823529411765
# test_Recall: 0.631578947368421
# test_F1: 0.6666666666666667
# test_MCC: 0.4314701674469593
# test_roc_auc: 0.7123411978221416
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 1, 0.6, 150)
# val_ACC: 0.6889762131478594
# val_Precision: 0.6639742634255194
# val_Recall: 0.5773934196922703
# val_F1: 0.6174721271774185
# test_ACC: 0.7181467181467182
# test_Precision: 0.7029702970297029
# test_Recall: 0.6228070175438597
# test_F1: 0.6604651162790697
# test_MCC: 0.4232988078400393
# test_roc_auc: 0.7079552329098608
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 0.9, 0.8, 140)
# val_ACC: 0.6870464926928225
# val_Precision: 0.6606358651759427
# val_Recall: 0.5778884631758194
# val_F1: 0.6162334345674598
# test_ACC: 0.7181467181467182
# test_Precision: 0.7070707070707071
# test_Recall: 0.6140350877192983
# test_F1: 0.6572769953051644
# test_MCC: 0.4229567745088846
# test_roc_auc: 0.7070175438596492
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 0.9, 0.8, 150)
# val_ACC: 0.6870464926928225
# val_Precision: 0.6606358651759427
# val_Recall: 0.5778884631758194
# val_F1: 0.6162334345674598
# test_ACC: 0.7181467181467182
# test_Precision: 0.7070707070707071
# test_Recall: 0.6140350877192983
# test_F1: 0.6572769953051644
# test_MCC: 0.4229567745088846
# test_roc_auc: 0.7070175438596492
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 0.9, 0.8, 150)
# val_ACC: 0.6870464926928225
# val_Precision: 0.6606358651759427
# val_Recall: 0.5778884631758194
# val_F1: 0.6162334345674598
# test_ACC: 0.7181467181467182
# test_Precision: 0.7070707070707071
# test_Recall: 0.6140350877192983
# test_F1: 0.6572769953051644
# test_MCC: 0.4229567745088846
# test_roc_auc: 0.7070175438596492
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 4, 1, 0.8, 160)
# val_ACC: 0.6872594749504345
# val_Precision: 0.6620658487280919
# val_Recall: 0.5749303655050781
# val_F1: 0.6151340064119107
# test_ACC: 0.7142857142857143
# test_Precision: 0.698019801980198
# test_Recall: 0.618421052631579
# test_F1: 0.6558139534883721
# test_MCC: 0.4153253975687251
# test_roc_auc: 0.704038112522686
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 1, 1.0, 150)
# val_ACC: 0.6881134740028244
# val_Precision: 0.6621295938344096
# val_Recall: 0.5783895882746457
# val_F1: 0.6172122521134351
# test_ACC: 0.7123552123552124
# test_Precision: 0.6984924623115578
# test_Recall: 0.6096491228070176
# test_F1: 0.6510538641686183
# test_MCC: 0.41103884280334463
# test_roc_auc: 0.7013762855414398
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 1, 1.0, 150)
# val_ACC: 0.6881134740028244
# val_Precision: 0.6621295938344096
# val_Recall: 0.5783895882746457
# val_F1: 0.6172122521134351
# test_ACC: 0.7123552123552124
# test_Precision: 0.6984924623115578
# test_Recall: 0.6096491228070176
# test_F1: 0.6510538641686183
# test_MCC: 0.41103884280334463
# test_roc_auc: 0.7013762855414398
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.6, 140)
# val_ACC: 0.6969119872670652
# val_Precision: 0.6800400658820273
# val_Recall: 0.5734476677005412
# val_F1: 0.6217484768526218
# test_ACC: 0.7084942084942085
# test_Precision: 0.6974358974358974
# test_Recall: 0.5964912280701754
# test_F1: 0.6430260047281324
# test_MCC: 0.4027057853362581
# test_roc_auc: 0.6965214761040533
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.6, 150)
# val_ACC: 0.6969119872670652
# val_Precision: 0.6800400658820273
# val_Recall: 0.5734476677005412
# val_F1: 0.6217484768526218
# test_ACC: 0.7084942084942085
# test_Precision: 0.6974358974358974
# test_Recall: 0.5964912280701754
# test_F1: 0.6430260047281324
# test_MCC: 0.4027057853362581
# test_roc_auc: 0.6965214761040533
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.6, 150)
# val_ACC: 0.6969119872670652
# val_Precision: 0.6800400658820273
# val_Recall: 0.5734476677005412
# val_F1: 0.6217484768526218
# test_ACC: 0.7084942084942085
# test_Precision: 0.6974358974358974
# test_Recall: 0.5964912280701754
# test_F1: 0.6430260047281324
# test_MCC: 0.4027057853362581
# test_roc_auc: 0.6965214761040533
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.6, 160)
# val_ACC: 0.6969119872670652
# val_Precision: 0.6800400658820273
# val_Recall: 0.5734476677005412
# val_F1: 0.6217484768526218
# test_ACC: 0.7084942084942085
# test_Precision: 0.6974358974358974
# test_Recall: 0.5964912280701754
# test_F1: 0.6430260047281324
# test_MCC: 0.4027057853362581
# test_roc_auc: 0.6965214761040533
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.08, 6, 1, 0.6, 140)
# val_ACC: 0.6969119872670652
# val_Precision: 0.6800400658820273
# val_Recall: 0.5734476677005412
# val_F1: 0.6217484768526218
# test_ACC: 0.7084942084942085
# test_Precision: 0.6974358974358974
# test_Recall: 0.5964912280701754
# test_F1: 0.6430260047281324
# test_MCC: 0.4027057853362581
# test_roc_auc: 0.6965214761040533
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 0.6, 150)
# val_ACC: 0.6928400241042555
# val_Precision: 0.673528048099352
# val_Recall: 0.5719710515112815
# val_F1: 0.6181659344832967
# test_ACC: 0.7027027027027027
# test_Precision: 0.6868686868686869
# test_Recall: 0.5964912280701754
# test_F1: 0.6384976525821596
# test_MCC: 0.3909445580863828
# test_roc_auc: 0.6913490623109498
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf: (0.1, 6, 0.9, 0.6, 140)
# val_ACC: 0.6928400241042555
# val_Precision: 0.673528048099352
# val_Recall: 0.5719710515112815
# val_F1: 0.6181659344832967
# test_ACC: 0.7027027027027027
# test_Precision: 0.6868686868686869
# test_Recall: 0.5964912280701754
# test_F1: 0.6384976525821596
# test_MCC: 0.3909445580863828
# test_roc_auc: 0.6913490623109498
# ------------------------------------------------------------
