# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from catboost import CatBoostClassifier
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_predict, GridSearchCV
from itertools import product
import random
from tqdm import tqdm

# %%
# training dataset loading
Training_csv_file_path = './data/TrainingSet/mRNA_sublocation_TrainingSet_hfeature.csv'
Training_data= pd.read_csv(Training_csv_file_path)
Training_data
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.008038  0.005472  0.007248  0.007894  0.007398  0.004448  0.000894
# 1     0.006421  0.004846  0.007124  0.006833  0.007555  0.005529  0.002641
# 2     0.012833  0.005971  0.006511  0.007626  0.007715  0.005825  0.001119
# 3     0.013917  0.006805  0.005778  0.013393  0.008006  0.004290  0.000706
# 4     0.017324  0.006722  0.007164  0.007420  0.007784  0.003431  0.001093
# ...        ...       ...       ...       ...       ...       ...       ...
# 4657  0.020823  0.006709  0.006760  0.009948  0.007638  0.003582  0.001047
# 4658  0.002121  0.007038  0.006064  0.003244  0.007038  0.005526  0.002388
# 4659  0.018389  0.005796  0.007591  0.005788  0.005100  0.006153  0.002046
# 4660  0.001512  0.001544  0.005322  0.000000  0.003088  0.007880  0.001362
# 4661  0.006508  0.003946  0.005190  0.002074  0.002492  0.006784  0.002657
#
#              7         8         9  ...        62        63  Z-Curve_X  \
# 0     0.007232  0.009605  0.007154  ...  0.007301  0.012933        183
# 1     0.006684  0.008229  0.006792  ...  0.007317  0.014494         20
# 2     0.006599  0.007285  0.005525  ...  0.006162  0.012829        248
# 3     0.007448  0.006812  0.002914  ...  0.006759  0.023986       -211
# 4     0.007214  0.006707  0.006244  ...  0.006850  0.013950        178
# ...        ...       ...       ...  ...       ...       ...        ...
# 4657  0.007103  0.007427  0.004873  ...  0.007436  0.016279        267
# 4658  0.005519  0.008397  0.006210  ...  0.003900  0.006741         -1
# 4659  0.007090  0.005993  0.006751  ...  0.004802  0.011305         29
# 4660  0.001574  0.003991  0.010899  ...  0.000000  0.000000         -2
# 4661  0.002541  0.005190  0.005315  ...  0.004489  0.006680        -69
#
#       Z-Curve_Y  Z-Curve_Z  gcContent     AT/GC   GC skew   AT skew  label
# 0           -31        381  45.001312  0.062391  0.036260  1.222157      1
# 1           -16        122  47.749077  0.013910  0.001412  1.094281      1
# 2           152       1736  44.059677  0.007456  0.024468  1.269649      1
# 3           -43       1183  34.672195 -0.062780 -0.050377  1.884155      1
# 4           -46        320  42.673993  0.120172  0.052716  1.343348      1
# ...         ...        ...        ...       ...       ...       ...    ...
# 4657         57       1591  39.366395  0.035654  0.035714  1.540238      0
# 4658         -1         -1  50.069930  0.000000 -0.002801  0.997207      0
# 4659         73         91  47.270546 -0.027919  0.058020  1.115482      0
# 4660         10       -108  71.428571 -0.033333  0.055556  0.400000      0
# 4661         15      -1033  63.888142 -0.017677 -0.020104  0.565236      0
#
# [4662 rows x 72 columns]

# %%
# test dataset loading
Test_csv_file_path = './data/TestSet/mRNA_sublocation_TestSet_hfeature.csv'
Test_data= pd.read_csv(Test_csv_file_path)
Test_data
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.011010  0.005166  0.007069  0.009104  0.006584  0.004962  0.000983
# 1    0.001138  0.002840  0.004449  0.000387  0.005293  0.008433  0.003076
# 2    0.003841  0.003923  0.006374  0.003134  0.005604  0.007207  0.001879
# 3    0.004768  0.003772  0.005141  0.003835  0.004800  0.007349  0.002178
# 4    0.014964  0.005276  0.007248  0.011185  0.005625  0.003709  0.000834
# ..        ...       ...       ...       ...       ...       ...       ...
# 513  0.002883  0.003271  0.005074  0.002614  0.003925  0.005676  0.004618
# 514  0.008520  0.004350  0.004851  0.005622  0.003838  0.005746  0.001919
# 515  0.003307  0.003241  0.005121  0.002833  0.005537  0.005652  0.001430
# 516  0.004880  0.002683  0.006275  0.003445  0.004216  0.005869  0.002368
# 517  0.003484  0.002668  0.004598  0.004885  0.006671  0.004085  0.005101
#
#             7         8         9  ...        62        63  Z-Curve_X  \
# 0    0.006195  0.007331  0.005005  ...  0.007570  0.013872        167
# 1    0.004343  0.004783  0.009227  ...  0.002325  0.003215       -150
# 2    0.005027  0.005505  0.008505  ...  0.003533  0.003954        -72
# 3    0.004614  0.005968  0.006595  ...  0.005558  0.009890       -345
# 4    0.006393  0.007677  0.003865  ...  0.007978  0.021691       -181
# ..        ...       ...       ...  ...       ...       ...        ...
# 513  0.003668  0.004228  0.007505  ...  0.003535  0.002715          4
# 514  0.007434  0.004079  0.004629  ...  0.006452  0.013806       -211
# 515  0.006058  0.006633  0.008223  ...  0.005108  0.005465         12
# 516  0.002345  0.005615  0.008456  ...  0.003107  0.001193         45
# 517  0.003627  0.008430  0.006278  ...  0.004005  0.003691         50
#
#      Z-Curve_Y  Z-Curve_Z  gcContent     AT/GC   GC skew   AT skew  label
# 0         -101        433  44.322056  0.079290  0.015544  1.256213      1
# 1           68       -770  62.867647 -0.057948 -0.036904  0.590643      1
# 2           62       -512  57.428903 -0.033855 -0.003408  0.741283      1
# 3         -101       -377  53.347540 -0.040613 -0.084888  0.874501      1
# 4         -467       2243  35.542091  0.051868 -0.064800  1.813565      1
# ..         ...        ...        ...       ...       ...       ...    ...
# 513         -8       -338  64.297800  0.007895 -0.004739  0.555263      0
# 514       -169         97  48.393508 -0.014374 -0.121951  1.066393      0
# 515        -96       -424  57.412587  0.032887 -0.034483  0.741778      0
# 516         13       -295  64.618434  0.024540  0.081232  0.547546      0
# 517        -20       -172  59.885057  0.067179  0.042980  0.669866      0
#
# [518 rows x 72 columns]

# %%
# separate sequence features and labels
X_train = Training_data.drop(columns=['label']).values
y_train = Training_data['label'].values

X_test = Test_data.drop(columns=['label']).values
y_test = Test_data['label'].values

# the training data and test data are standardized
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
# Random search was used, and the number of hyperparameters searched was defined
num = 100
# Define the hyperparameter search space
learning_rate = [0.08,0.1]
depth = [4, 5, 6]
rsm = [0.9, 1]
subsample = [0.6, 0.8, 1.0]
min_data_in_leaf = [140,150,160]

seed_value = 42
random.seed(seed_value)
# Hyperparameter tuning
hyperparameter_space = list(product(learning_rate,depth,rsm,subsample,min_data_in_leaf))
hyperparameters = [random.choice(hyperparameter_space) for i in range(num)]
results = []
best_acc = 0
for hyperparameter in tqdm(hyperparameters, desc="Hyperparameter Search"):
    learning_rate,depth,rsm,subsample,min_data_in_leaf = hyperparameter
 
    val_accuracy_scores = []
    val_precision_scores = []
    val_recall_scores = []
    val_f1_scores = []
    
    #     5-fold cross-validation
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for fold, (train_index, val_index) in enumerate(kf.split(X_train,y_train), 1):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        clf = CatBoostClassifier(iterations=1000,learning_rate=learning_rate,depth=depth,rsm=rsm,subsample=subsample,min_data_in_leaf=min_data_in_leaf, logging_level='Silent',early_stopping_rounds=50)
        
        clf.fit(X_train_fold,y_train_fold)
     
        val_predictions = clf.predict(X_val_fold)
        val_accuracy = accuracy_score(y_val_fold, val_predictions)
        val_precision = precision_score(y_val_fold, val_predictions)
        val_recall = recall_score(y_val_fold, val_predictions)
        val_f1 = f1_score(y_val_fold, val_predictions)

#         Saving metrics
        val_accuracy_scores.append(val_accuracy)
        val_precision_scores.append(val_precision)
        val_recall_scores.append(val_recall)
        val_f1_scores.append(val_f1)
#   The average value of each metric was calculated
    val_ACC = np.mean(val_accuracy_scores)
    val_Precision = np.mean(val_precision_scores)
    val_Recall = np.mean(val_recall_scores)
    val_F1 = np.mean(val_f1_scores)
    
# Independent testing
    clf.fit(X_train,y_train)
    test_predictions = clf.predict(X_test)
    cm = confusion_matrix(y_test,test_predictions)
    TP = cm[1, 1]
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]

    test_ACC = accuracy_score(y_test, test_predictions)
    test_Precision = precision_score(y_test, test_predictions)
    test_Recall = recall_score(y_test, test_predictions)
    test_F1 = f1_score(y_test, test_predictions)
    mcc = (TP * TN - FP * FN) / ((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))**0.5

    fpr, tpr, thresholds = roc_curve(y_test, test_predictions, pos_label=1)
    roc_auc = auc(fpr, tpr)
    
    
   
    

    results.append({
        "超参数组合": hyperparameter,
        "val_ACC": val_ACC,
        "val_Precision": val_Precision,
        "val_Recall": val_Recall,
        "val_F1":val_F1,
        "test_ACC":test_ACC,      
        "test_Precision":test_Precision,
        "test_Recall":test_Recall,
        "test_F1":test_F1,
        "test_MCC":mcc,
        "test_roc_auc":roc_auc
    })
# Out:
# Hyperparameter Search: 100%|█████████████████████████████████████████████████████████| 100/100 [58:16<00:00, 34.97s/it]

# %%
# result ranking
sorted_results = sorted(results, key=lambda x: x["val_ACC"], reverse=True)
for i,result in enumerate(sorted_results):
    print("超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf :", result["超参数组合"])
    print("val_ACC:", result["val_ACC"])
    print("val_Precision:", result["val_Precision"])
    print("val_Recall:", result["val_Recall"])
    print("val_F1:", result["val_F1"])
    print("test_ACC:", result["test_ACC"])
    print("test_Precision:", result["test_Precision"])
    print("test_Recall:", result["test_Recall"])
    print("test_F1:", result["test_F1"])
    print("test_MCC:", result["test_MCC"])
    print("test_roc_auc:", result["test_roc_auc"])
    print("-" * 60)
# Out:
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 0.6, 140)
# val_ACC: 0.6799665576455111
# val_Precision: 0.6591396352796444
# val_Recall: 0.5483062701453505
# val_F1: 0.5983976020099446
# test_ACC: 0.7142857142857143
# test_Precision: 0.7061855670103093
# test_Recall: 0.6008771929824561
# test_F1: 0.6492890995260664
# test_MCC: 0.41469056189449516
# test_roc_auc: 0.7021627344222625
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 0.6, 150)
# val_ACC: 0.6786748639535579
# val_Precision: 0.6528507159112944
# val_Recall: 0.55816091954023
# val_F1: 0.6015936707087581
# test_ACC: 0.7200772200772201
# test_Precision: 0.6948356807511737
# test_Recall: 0.6491228070175439
# test_F1: 0.671201814058957
# test_MCC: 0.4287460935470322
# test_roc_auc: 0.7124924379915305
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.6, 140)
# val_ACC: 0.6786744039486818
# val_Precision: 0.659018107865273
# val_Recall: 0.5413939062214925
# val_F1: 0.5940768752654024
# test_ACC: 0.7393822393822393
# test_Precision: 0.746031746031746
# test_Recall: 0.618421052631579
# test_F1: 0.6762589928057554
# test_MCC: 0.4670286752084742
# test_roc_auc: 0.7264519056261343
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.6, 150)
# val_ACC: 0.6786744039486818
# val_Precision: 0.659018107865273
# val_Recall: 0.5413939062214925
# val_F1: 0.5940768752654024
# test_ACC: 0.7393822393822393
# test_Precision: 0.746031746031746
# test_Recall: 0.618421052631579
# test_F1: 0.6762589928057554
# test_MCC: 0.4670286752084742
# test_roc_auc: 0.7264519056261343
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.6, 150)
# val_ACC: 0.6786744039486818
# val_Precision: 0.659018107865273
# val_Recall: 0.5413939062214925
# val_F1: 0.5940768752654024
# test_ACC: 0.7393822393822393
# test_Precision: 0.746031746031746
# test_Recall: 0.618421052631579
# test_F1: 0.6762589928057554
# test_MCC: 0.4670286752084742
# test_roc_auc: 0.7264519056261343
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.6, 160)
# val_ACC: 0.6786744039486818
# val_Precision: 0.659018107865273
# val_Recall: 0.5413939062214925
# val_F1: 0.5940768752654024
# test_ACC: 0.7393822393822393
# test_Precision: 0.746031746031746
# test_Recall: 0.618421052631579
# test_F1: 0.6762589928057554
# test_MCC: 0.4670286752084742
# test_roc_auc: 0.7264519056261343
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.6, 140)
# val_ACC: 0.6786744039486818
# val_Precision: 0.659018107865273
# val_Recall: 0.5413939062214925
# val_F1: 0.5940768752654024
# test_ACC: 0.7393822393822393
# test_Precision: 0.746031746031746
# test_Recall: 0.618421052631579
# test_F1: 0.6762589928057554
# test_MCC: 0.4670286752084742
# test_roc_auc: 0.7264519056261343
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 1.0, 150)
# val_ACC: 0.678248439433458
# val_Precision: 0.6552435229040785
# val_Recall: 0.5498035638265523
# val_F1: 0.5976732560746001
# test_ACC: 0.7393822393822393
# test_Precision: 0.7336683417085427
# test_Recall: 0.6403508771929824
# test_F1: 0.6838407494145199
# test_MCC: 0.4670068054021027
# test_roc_auc: 0.7287961282516636
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 1.0, 150)
# val_ACC: 0.678248439433458
# val_Precision: 0.6552435229040785
# val_Recall: 0.5498035638265523
# val_F1: 0.5976732560746001
# test_ACC: 0.7393822393822393
# test_Precision: 0.7336683417085427
# test_Recall: 0.6403508771929824
# test_F1: 0.6838407494145199
# test_MCC: 0.4670068054021027
# test_roc_auc: 0.7287961282516636
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 1.0, 160)
# val_ACC: 0.678248439433458
# val_Precision: 0.6552435229040785
# val_Recall: 0.5498035638265523
# val_F1: 0.5976732560746001
# test_ACC: 0.7393822393822393
# test_Precision: 0.7336683417085427
# test_Recall: 0.6403508771929824
# test_F1: 0.6838407494145199
# test_MCC: 0.4670068054021027
# test_roc_auc: 0.7287961282516636
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.8, 160)
# val_ACC: 0.6782449893968876
# val_Precision: 0.6583730410183631
# val_Recall: 0.5418925986742079
# val_F1: 0.5942086981727076
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.8, 140)
# val_ACC: 0.6782449893968876
# val_Precision: 0.6583730410183631
# val_Recall: 0.5418925986742079
# val_F1: 0.5942086981727076
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.8, 150)
# val_ACC: 0.6782449893968876
# val_Precision: 0.6583730410183631
# val_Recall: 0.5418925986742079
# val_F1: 0.5942086981727076
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 0.8, 140)
# val_ACC: 0.6780297071148954
# val_Precision: 0.6565242751939004
# val_Recall: 0.543864258347017
# val_F1: 0.5946918042041116
# test_ACC: 0.7200772200772201
# test_Precision: 0.7106598984771574
# test_Recall: 0.6140350877192983
# test_F1: 0.6588235294117647
# test_MCC: 0.42689391759656276
# test_roc_auc: 0.7087416817906835
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6780297071148954
# val_Precision: 0.6565242751939004
# val_Recall: 0.543864258347017
# val_F1: 0.5946918042041116
# test_ACC: 0.7200772200772201
# test_Precision: 0.7106598984771574
# test_Recall: 0.6140350877192983
# test_F1: 0.6588235294117647
# test_MCC: 0.42689391759656276
# test_roc_auc: 0.7087416817906835
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 0.8, 140)
# val_ACC: 0.6780297071148954
# val_Precision: 0.6565242751939004
# val_Recall: 0.543864258347017
# val_F1: 0.5946918042041116
# test_ACC: 0.7200772200772201
# test_Precision: 0.7106598984771574
# test_Recall: 0.6140350877192983
# test_F1: 0.6588235294117647
# test_MCC: 0.42689391759656276
# test_roc_auc: 0.7087416817906835
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6780297071148954
# val_Precision: 0.6565242751939004
# val_Recall: 0.543864258347017
# val_F1: 0.5946918042041116
# test_ACC: 0.7200772200772201
# test_Precision: 0.7106598984771574
# test_Recall: 0.6140350877192983
# test_F1: 0.6588235294117647
# test_MCC: 0.42689391759656276
# test_roc_auc: 0.7087416817906835
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 0.8, 160)
# val_ACC: 0.6780297071148954
# val_Precision: 0.6565242751939004
# val_Recall: 0.543864258347017
# val_F1: 0.5946918042041116
# test_ACC: 0.7200772200772201
# test_Precision: 0.7106598984771574
# test_Recall: 0.6140350877192983
# test_F1: 0.6588235294117647
# test_MCC: 0.42689391759656276
# test_roc_auc: 0.7087416817906835
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.6767451434985211
# val_Precision: 0.6551333748713944
# val_Recall: 0.5418974639664295
# val_F1: 0.5930764405700433
# test_ACC: 0.7374517374517374
# test_Precision: 0.7421052631578947
# test_Recall: 0.618421052631579
# test_F1: 0.6746411483253588
# test_MCC: 0.46295569786838026
# test_roc_auc: 0.7247277676950998
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.6767451434985211
# val_Precision: 0.6551333748713944
# val_Recall: 0.5418974639664295
# val_F1: 0.5930764405700433
# test_ACC: 0.7374517374517374
# test_Precision: 0.7421052631578947
# test_Recall: 0.618421052631579
# test_F1: 0.6746411483253588
# test_MCC: 0.46295569786838026
# test_roc_auc: 0.7247277676950998
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 0.8, 150)
# val_ACC: 0.6767451434985211
# val_Precision: 0.6551333748713944
# val_Recall: 0.5418974639664295
# val_F1: 0.5930764405700433
# test_ACC: 0.7374517374517374
# test_Precision: 0.7421052631578947
# test_Recall: 0.618421052631579
# test_F1: 0.6746411483253588
# test_MCC: 0.46295569786838026
# test_roc_auc: 0.7247277676950998
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 0.8, 140)
# val_ACC: 0.6767451434985211
# val_Precision: 0.6551333748713944
# val_Recall: 0.5418974639664295
# val_F1: 0.5930764405700433
# test_ACC: 0.7374517374517374
# test_Precision: 0.7421052631578947
# test_Recall: 0.618421052631579
# test_F1: 0.6746411483253588
# test_MCC: 0.46295569786838026
# test_roc_auc: 0.7247277676950998
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 0.9, 0.8, 140)
# val_ACC: 0.6765330812506611
# val_Precision: 0.653836498180131
# val_Recall: 0.5458395669889923
# val_F1: 0.5945613342658361
# test_ACC: 0.7258687258687259
# test_Precision: 0.7128712871287128
# test_Recall: 0.631578947368421
# test_F1: 0.6697674418604651
# test_MCC: 0.4392456283826677
# test_roc_auc: 0.7157894736842105
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 0.9, 0.8, 150)
# val_ACC: 0.6765330812506611
# val_Precision: 0.653836498180131
# val_Recall: 0.5458395669889923
# val_F1: 0.5945613342658361
# test_ACC: 0.7258687258687259
# test_Precision: 0.7128712871287128
# test_Recall: 0.631578947368421
# test_F1: 0.6697674418604651
# test_MCC: 0.4392456283826677
# test_roc_auc: 0.7157894736842105
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 0.9, 0.8, 150)
# val_ACC: 0.6765330812506611
# val_Precision: 0.653836498180131
# val_Recall: 0.5458395669889923
# val_F1: 0.5945613342658361
# test_ACC: 0.7258687258687259
# test_Precision: 0.7128712871287128
# test_Recall: 0.631578947368421
# test_F1: 0.6697674418604651
# test_MCC: 0.4392456283826677
# test_roc_auc: 0.7157894736842105
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.8, 160)
# val_ACC: 0.6763143489320986
# val_Precision: 0.6543892940898527
# val_Recall: 0.5423827768655355
# val_F1: 0.592852325077344
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.8, 150)
# val_ACC: 0.6763143489320986
# val_Precision: 0.6543892940898527
# val_Recall: 0.5423827768655355
# val_F1: 0.592852325077344
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.8, 150)
# val_ACC: 0.6763143489320986
# val_Precision: 0.6543892940898527
# val_Recall: 0.5423827768655355
# val_F1: 0.592852325077344
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.8, 140)
# val_ACC: 0.6763143489320986
# val_Precision: 0.6543892940898527
# val_Recall: 0.5423827768655355
# val_F1: 0.592852325077344
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.8, 140)
# val_ACC: 0.6763143489320986
# val_Precision: 0.6543892940898527
# val_Recall: 0.5423827768655355
# val_F1: 0.592852325077344
# test_ACC: 0.7181467181467182
# test_Precision: 0.7204301075268817
# test_Recall: 0.5877192982456141
# test_F1: 0.6473429951690822
# test_MCC: 0.42260649062784966
# test_roc_auc: 0.7042044767090139
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 0.9, 0.6, 140)
# val_ACC: 0.6758874644071227
# val_Precision: 0.6516877404982847
# val_Recall: 0.547810010338746
# val_F1: 0.5949763307701255
# test_ACC: 0.7065637065637066
# test_Precision: 0.6919191919191919
# test_Recall: 0.6008771929824561
# test_F1: 0.6431924882629109
# test_MCC: 0.39894761219200825
# test_roc_auc: 0.6952661826981246
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 0.9, 0.6, 140)
# val_ACC: 0.6758874644071227
# val_Precision: 0.6516877404982847
# val_Recall: 0.547810010338746
# val_F1: 0.5949763307701255
# test_ACC: 0.7065637065637066
# test_Precision: 0.6919191919191919
# test_Recall: 0.6008771929824561
# test_F1: 0.6431924882629109
# test_MCC: 0.39894761219200825
# test_roc_auc: 0.6952661826981246
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6758865443973706
# val_Precision: 0.6550636873119096
# val_Recall: 0.5384394575199172
# val_F1: 0.5907525130406354
# test_ACC: 0.7104247104247104
# test_Precision: 0.6989795918367347
# test_Recall: 0.6008771929824561
# test_F1: 0.6462264150943396
# test_MCC: 0.4067896684910706
# test_roc_auc: 0.6987144585601937
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 0.8, 150)
# val_ACC: 0.6758865443973706
# val_Precision: 0.6550636873119096
# val_Recall: 0.5384394575199172
# val_F1: 0.5907525130406354
# test_ACC: 0.7104247104247104
# test_Precision: 0.6989795918367347
# test_Recall: 0.6008771929824561
# test_F1: 0.6462264150943396
# test_MCC: 0.4067896684910706
# test_roc_auc: 0.6987144585601937
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6758865443973706
# val_Precision: 0.6550636873119096
# val_Recall: 0.5384394575199172
# val_F1: 0.5907525130406354
# test_ACC: 0.7104247104247104
# test_Precision: 0.6989795918367347
# test_Recall: 0.6008771929824561
# test_F1: 0.6462264150943396
# test_MCC: 0.4067896684910706
# test_roc_auc: 0.6987144585601937
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 0.8, 140)
# val_ACC: 0.6758865443973706
# val_Precision: 0.6550636873119096
# val_Recall: 0.5384394575199172
# val_F1: 0.5907525130406354
# test_ACC: 0.7104247104247104
# test_Precision: 0.6989795918367347
# test_Recall: 0.6008771929824561
# test_F1: 0.6462264150943396
# test_MCC: 0.4067896684910706
# test_roc_auc: 0.6987144585601937
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 0.8, 160)
# val_ACC: 0.6758865443973706
# val_Precision: 0.6550636873119096
# val_Recall: 0.5384394575199172
# val_F1: 0.5907525130406354
# test_ACC: 0.7104247104247104
# test_Precision: 0.6989795918367347
# test_Recall: 0.6008771929824561
# test_F1: 0.6462264150943396
# test_MCC: 0.4067896684910706
# test_roc_auc: 0.6987144585601937
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 0.8, 160)
# val_ACC: 0.6758865443973706
# val_Precision: 0.6550636873119096
# val_Recall: 0.5384394575199172
# val_F1: 0.5907525130406354
# test_ACC: 0.7104247104247104
# test_Precision: 0.6989795918367347
# test_Recall: 0.6008771929824561
# test_F1: 0.6462264150943396
# test_MCC: 0.4067896684910706
# test_roc_auc: 0.6987144585601937
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.6, 150)
# val_ACC: 0.6754578198528904
# val_Precision: 0.6505584263430633
# val_Recall: 0.5487940156905674
# val_F1: 0.594986172524288
# test_ACC: 0.7297297297297297
# test_Precision: 0.7291666666666666
# test_Recall: 0.6140350877192983
# test_F1: 0.6666666666666667
# test_MCC: 0.44680843920044344
# test_roc_auc: 0.717362371445856
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.6, 140)
# val_ACC: 0.6754578198528904
# val_Precision: 0.6505584263430633
# val_Recall: 0.5487940156905674
# val_F1: 0.594986172524288
# test_ACC: 0.7297297297297297
# test_Precision: 0.7291666666666666
# test_Recall: 0.6140350877192983
# test_F1: 0.6666666666666667
# test_MCC: 0.44680843920044344
# test_roc_auc: 0.717362371445856
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6754578198528904
# val_Precision: 0.6505584263430633
# val_Recall: 0.5487940156905674
# val_F1: 0.594986172524288
# test_ACC: 0.7297297297297297
# test_Precision: 0.7291666666666666
# test_Recall: 0.6140350877192983
# test_F1: 0.6666666666666667
# test_MCC: 0.44680843920044344
# test_roc_auc: 0.717362371445856
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.6, 150)
# val_ACC: 0.6754578198528904
# val_Precision: 0.6505584263430633
# val_Recall: 0.5487940156905674
# val_F1: 0.594986172524288
# test_ACC: 0.7297297297297297
# test_Precision: 0.7291666666666666
# test_Recall: 0.6140350877192983
# test_F1: 0.6666666666666667
# test_MCC: 0.44680843920044344
# test_roc_auc: 0.717362371445856
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.6, 140)
# val_ACC: 0.6754578198528904
# val_Precision: 0.6505584263430633
# val_Recall: 0.5487940156905674
# val_F1: 0.594986172524288
# test_ACC: 0.7297297297297297
# test_Precision: 0.7291666666666666
# test_Recall: 0.6140350877192983
# test_F1: 0.6666666666666667
# test_MCC: 0.44680843920044344
# test_roc_auc: 0.717362371445856
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6754578198528904
# val_Precision: 0.6505584263430633
# val_Recall: 0.5487940156905674
# val_F1: 0.594986172524288
# test_ACC: 0.7297297297297297
# test_Precision: 0.7291666666666666
# test_Recall: 0.6140350877192983
# test_F1: 0.6666666666666667
# test_MCC: 0.44680843920044344
# test_roc_auc: 0.717362371445856
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.6, 160)
# val_ACC: 0.6754578198528904
# val_Precision: 0.6505584263430633
# val_Recall: 0.5487940156905674
# val_F1: 0.594986172524288
# test_ACC: 0.7297297297297297
# test_Precision: 0.7291666666666666
# test_Recall: 0.6140350877192983
# test_F1: 0.6666666666666667
# test_MCC: 0.44680843920044344
# test_roc_auc: 0.717362371445856
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6750297853157243
# val_Precision: 0.6499371016567682
# val_Recall: 0.5483026211761844
# val_F1: 0.59449335207653
# test_ACC: 0.7316602316602316
# test_Precision: 0.7213930348258707
# test_Recall: 0.6359649122807017
# test_F1: 0.675990675990676
# test_MCC: 0.45113513727021665
# test_roc_auc: 0.7214307320024198
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6750297853157243
# val_Precision: 0.6499371016567682
# val_Recall: 0.5483026211761844
# val_F1: 0.59449335207653
# test_ACC: 0.7316602316602316
# test_Precision: 0.7213930348258707
# test_Recall: 0.6359649122807017
# test_F1: 0.675990675990676
# test_MCC: 0.45113513727021665
# test_roc_auc: 0.7214307320024198
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.6, 160)
# val_ACC: 0.6750297853157243
# val_Precision: 0.6499371016567682
# val_Recall: 0.5483026211761844
# val_F1: 0.59449335207653
# test_ACC: 0.7316602316602316
# test_Precision: 0.7213930348258707
# test_Recall: 0.6359649122807017
# test_F1: 0.675990675990676
# test_MCC: 0.45113513727021665
# test_roc_auc: 0.7214307320024198
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.6, 150)
# val_ACC: 0.6750297853157243
# val_Precision: 0.6499371016567682
# val_Recall: 0.5483026211761844
# val_F1: 0.59449335207653
# test_ACC: 0.7316602316602316
# test_Precision: 0.7213930348258707
# test_Recall: 0.6359649122807017
# test_F1: 0.675990675990676
# test_MCC: 0.45113513727021665
# test_roc_auc: 0.7214307320024198
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.6, 150)
# val_ACC: 0.6750297853157243
# val_Precision: 0.6499371016567682
# val_Recall: 0.5483026211761844
# val_F1: 0.59449335207653
# test_ACC: 0.7316602316602316
# test_Precision: 0.7213930348258707
# test_Recall: 0.6359649122807017
# test_F1: 0.675990675990676
# test_MCC: 0.45113513727021665
# test_roc_auc: 0.7214307320024198
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 0.6, 140)
# val_ACC: 0.6750297853157243
# val_Precision: 0.6499371016567682
# val_Recall: 0.5483026211761844
# val_F1: 0.59449335207653
# test_ACC: 0.7316602316602316
# test_Precision: 0.7213930348258707
# test_Recall: 0.6359649122807017
# test_F1: 0.675990675990676
# test_MCC: 0.45113513727021665
# test_roc_auc: 0.7214307320024198
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 0.9, 0.6, 150)
# val_ACC: 0.674172336226764
# val_Precision: 0.6519763651294215
# val_Recall: 0.5389284193881896
# val_F1: 0.5898011624358961
# test_ACC: 0.7239382239382239
# test_Precision: 0.7135678391959799
# test_Recall: 0.6228070175438597
# test_F1: 0.6651053864168618
# test_MCC: 0.43502511248852666
# test_roc_auc: 0.7131276467029642
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 0.9, 0.6, 150)
# val_ACC: 0.674172336226764
# val_Precision: 0.6519763651294215
# val_Recall: 0.5389284193881896
# val_F1: 0.5898011624358961
# test_ACC: 0.7239382239382239
# test_Precision: 0.7135678391959799
# test_Recall: 0.6228070175438597
# test_F1: 0.6651053864168618
# test_MCC: 0.43502511248852666
# test_roc_auc: 0.7131276467029642
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 0.6, 150)
# val_ACC: 0.6739595839715901
# val_Precision: 0.6515757681532808
# val_Recall: 0.5399197226783434
# val_F1: 0.5902507565993084
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 0.9, 0.6, 140)
# val_ACC: 0.6739595839715901
# val_Precision: 0.6515757681532808
# val_Recall: 0.5399197226783434
# val_F1: 0.5902507565993084
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6735292494100438
# val_Precision: 0.648088770299559
# val_Recall: 0.546321230918932
# val_F1: 0.5925373538119804
# test_ACC: 0.7104247104247104
# test_Precision: 0.695
# test_Recall: 0.6096491228070176
# test_F1: 0.6495327102803738
# test_MCC: 0.4071381945629888
# test_roc_auc: 0.6996521476104053
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.6, 160)
# val_ACC: 0.6735292494100438
# val_Precision: 0.648088770299559
# val_Recall: 0.546321230918932
# val_F1: 0.5925373538119804
# test_ACC: 0.7104247104247104
# test_Precision: 0.695
# test_Recall: 0.6096491228070176
# test_F1: 0.6495327102803738
# test_MCC: 0.4071381945629888
# test_roc_auc: 0.6996521476104053
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6735292494100438
# val_Precision: 0.648088770299559
# val_Recall: 0.546321230918932
# val_F1: 0.5925373538119804
# test_ACC: 0.7104247104247104
# test_Precision: 0.695
# test_Recall: 0.6096491228070176
# test_F1: 0.6495327102803738
# test_MCC: 0.4071381945629888
# test_roc_auc: 0.6996521476104053
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.6, 150)
# val_ACC: 0.6735292494100438
# val_Precision: 0.648088770299559
# val_Recall: 0.546321230918932
# val_F1: 0.5925373538119804
# test_ACC: 0.7104247104247104
# test_Precision: 0.695
# test_Recall: 0.6096491228070176
# test_F1: 0.6495327102803738
# test_MCC: 0.4071381945629888
# test_roc_auc: 0.6996521476104053
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 0.6, 140)
# val_ACC: 0.6735292494100438
# val_Precision: 0.648088770299559
# val_Recall: 0.546321230918932
# val_F1: 0.5925373538119804
# test_ACC: 0.7104247104247104
# test_Precision: 0.695
# test_Recall: 0.6096491228070176
# test_F1: 0.6495327102803738
# test_MCC: 0.4071381945629888
# test_roc_auc: 0.6996521476104053
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 0.9, 1.0, 150)
# val_ACC: 0.6724555980293391
# val_Precision: 0.6489618340593645
# val_Recall: 0.5384528370735268
# val_F1: 0.5884333339373309
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 0.9, 1.0, 140)
# val_ACC: 0.6724555980293391
# val_Precision: 0.6489618340593645
# val_Recall: 0.5384528370735268
# val_F1: 0.5884333339373309
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 0.9, 1.0, 160)
# val_ACC: 0.6724555980293391
# val_Precision: 0.6489618340593645
# val_Recall: 0.5384528370735268
# val_F1: 0.5884333339373309
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 0.9, 1.0, 160)
# val_ACC: 0.6722446857936694
# val_Precision: 0.6486461466602688
# val_Recall: 0.5399306695858419
# val_F1: 0.5889606432580894
# test_ACC: 0.7355212355212355
# test_Precision: 0.7241379310344828
# test_Recall: 0.6447368421052632
# test_F1: 0.6821345707656613
# test_MCC: 0.4592500082997134
# test_roc_auc: 0.7258166969147006
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.671599758957445
# val_Precision: 0.646099322890139
# val_Recall: 0.5428960651949158
# val_F1: 0.5897574807908466
# test_ACC: 0.7355212355212355
# test_Precision: 0.7286432160804021
# test_Recall: 0.6359649122807017
# test_F1: 0.6791569086651054
# test_MCC: 0.4590113821737087
# test_roc_auc: 0.7248790078644888
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.671599758957445
# val_Precision: 0.646099322890139
# val_Recall: 0.5428960651949158
# val_F1: 0.5897574807908466
# test_ACC: 0.7355212355212355
# test_Precision: 0.7286432160804021
# test_Recall: 0.6359649122807017
# test_F1: 0.6791569086651054
# test_MCC: 0.4590113821737087
# test_roc_auc: 0.7248790078644888
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 1.0, 160)
# val_ACC: 0.671599758957445
# val_Precision: 0.646099322890139
# val_Recall: 0.5428960651949158
# val_F1: 0.5897574807908466
# test_ACC: 0.7355212355212355
# test_Precision: 0.7286432160804021
# test_Recall: 0.6359649122807017
# test_F1: 0.6791569086651054
# test_MCC: 0.4590113821737087
# test_roc_auc: 0.7248790078644888
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 1, 1.0, 140)
# val_ACC: 0.671599758957445
# val_Precision: 0.646099322890139
# val_Recall: 0.5428960651949158
# val_F1: 0.5897574807908466
# test_ACC: 0.7355212355212355
# test_Precision: 0.7286432160804021
# test_Recall: 0.6359649122807017
# test_F1: 0.6791569086651054
# test_MCC: 0.4590113821737087
# test_roc_auc: 0.7248790078644888
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 0.9, 0.6, 160)
# val_ACC: 0.6709552921260965
# val_Precision: 0.6448509147183612
# val_Recall: 0.5419011129355956
# val_F1: 0.5888773309484365
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 0.9, 0.6, 150)
# val_ACC: 0.6709552921260965
# val_Precision: 0.6448509147183612
# val_Recall: 0.5419011129355956
# val_F1: 0.5888773309484365
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 0.9, 0.6, 160)
# val_ACC: 0.6709552921260965
# val_Precision: 0.6448509147183612
# val_Recall: 0.5419011129355956
# val_F1: 0.5888773309484365
# test_ACC: 0.7239382239382239
# test_Precision: 0.7114427860696517
# test_Recall: 0.6271929824561403
# test_F1: 0.6666666666666667
# test_MCC: 0.43517393235894203
# test_roc_auc: 0.7135964912280702
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 1, 0.8, 160)
# val_ACC: 0.6709532221041543
# val_Precision: 0.6449019705257509
# val_Recall: 0.5423803442194247
# val_F1: 0.5887356063275051
# test_ACC: 0.7123552123552124
# test_Precision: 0.6820276497695853
# test_Recall: 0.6491228070175439
# test_F1: 0.6651685393258429
# test_MCC: 0.4137116246654875
# test_roc_auc: 0.7055958862673926
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 1, 1.0, 140)
# val_ACC: 0.6700980730395741
# val_Precision: 0.6416604372641497
# val_Recall: 0.5473380769932493
# val_F1: 0.5905150420534842
# test_ACC: 0.7162162162162162
# test_Precision: 0.7014925373134329
# test_Recall: 0.618421052631579
# test_F1: 0.6573426573426574
# test_MCC: 0.41921272744766735
# test_roc_auc: 0.7057622504537205
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 1, 1.0, 160)
# val_ACC: 0.6700980730395741
# val_Precision: 0.6416604372641497
# val_Recall: 0.5473380769932493
# val_F1: 0.5905150420534842
# test_ACC: 0.7162162162162162
# test_Precision: 0.7014925373134329
# test_Recall: 0.618421052631579
# test_F1: 0.6573426573426574
# test_MCC: 0.41921272744766735
# test_roc_auc: 0.7057622504537205
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 1, 1.0, 140)
# val_ACC: 0.6700980730395741
# val_Precision: 0.6416604372641497
# val_Recall: 0.5473380769932493
# val_F1: 0.5905150420534842
# test_ACC: 0.7162162162162162
# test_Precision: 0.7014925373134329
# test_Recall: 0.618421052631579
# test_F1: 0.6573426573426574
# test_MCC: 0.41921272744766735
# test_roc_auc: 0.7057622504537205
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 1, 1.0, 150)
# val_ACC: 0.6700980730395741
# val_Precision: 0.6416604372641497
# val_Recall: 0.5473380769932493
# val_F1: 0.5905150420534842
# test_ACC: 0.7162162162162162
# test_Precision: 0.7014925373134329
# test_Recall: 0.618421052631579
# test_F1: 0.6573426573426574
# test_MCC: 0.41921272744766735
# test_roc_auc: 0.7057622504537205
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 1, 1.0, 150)
# val_ACC: 0.6700976130346983
# val_Precision: 0.6481228554336539
# val_Recall: 0.5295663808307487
# val_F1: 0.582468232074511
# test_ACC: 0.7277992277992278
# test_Precision: 0.7142857142857143
# test_Recall: 0.6359649122807017
# test_F1: 0.6728538283062645
# test_MCC: 0.4433172841486685
# test_roc_auc: 0.7179824561403509
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 1, 1.0, 150)
# val_ACC: 0.6700976130346983
# val_Precision: 0.6481228554336539
# val_Recall: 0.5295663808307487
# val_F1: 0.582468232074511
# test_ACC: 0.7277992277992278
# test_Precision: 0.7142857142857143
# test_Recall: 0.6359649122807017
# test_F1: 0.6728538283062645
# test_MCC: 0.4433172841486685
# test_roc_auc: 0.7179824561403509
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 4, 1, 0.6, 150)
# val_ACC: 0.6700971530298221
# val_Precision: 0.6430857176083209
# val_Recall: 0.5428863346104726
# val_F1: 0.5886327973115398
# test_ACC: 0.7065637065637066
# test_Precision: 0.69
# test_Recall: 0.6052631578947368
# test_F1: 0.6448598130841122
# test_MCC: 0.3991502548317704
# test_roc_auc: 0.6957350272232304
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6692392439359857
# val_Precision: 0.6474970027008828
# val_Recall: 0.5266022015447303
# val_F1: 0.5806105456019104
# test_ACC: 0.7142857142857143
# test_Precision: 0.7105263157894737
# test_Recall: 0.5921052631578947
# test_F1: 0.6459330143540669
# test_MCC: 0.4145383646368396
# test_roc_auc: 0.7012250453720508
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6692392439359857
# val_Precision: 0.6474970027008828
# val_Recall: 0.5266022015447303
# val_F1: 0.5806105456019104
# test_ACC: 0.7142857142857143
# test_Precision: 0.7105263157894737
# test_Recall: 0.5921052631578947
# test_F1: 0.6459330143540669
# test_MCC: 0.4145383646368396
# test_roc_auc: 0.7012250453720508
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 0.8, 140)
# val_ACC: 0.6692392439359857
# val_Precision: 0.6474970027008828
# val_Recall: 0.5266022015447303
# val_F1: 0.5806105456019104
# test_ACC: 0.7142857142857143
# test_Precision: 0.7105263157894737
# test_Recall: 0.5921052631578947
# test_F1: 0.6459330143540669
# test_MCC: 0.4145383646368396
# test_roc_auc: 0.7012250453720508
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.6677359480010487
# val_Precision: 0.643610473480124
# val_Recall: 0.5300541263759654
# val_F1: 0.581101335902425
# test_ACC: 0.7239382239382239
# test_Precision: 0.717948717948718
# test_Recall: 0.6140350877192983
# test_F1: 0.6619385342789598
# test_MCC: 0.4348131574778899
# test_roc_auc: 0.7121899576527526
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.6677359480010487
# val_Precision: 0.643610473480124
# val_Recall: 0.5300541263759654
# val_F1: 0.581101335902425
# test_ACC: 0.7239382239382239
# test_Precision: 0.717948717948718
# test_Recall: 0.6140350877192983
# test_F1: 0.6619385342789598
# test_MCC: 0.4348131574778899
# test_roc_auc: 0.7121899576527526
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 6, 1, 0.8, 150)
# val_ACC: 0.6677359480010487
# val_Precision: 0.643610473480124
# val_Recall: 0.5300541263759654
# val_F1: 0.581101335902425
# test_ACC: 0.7239382239382239
# test_Precision: 0.717948717948718
# test_Recall: 0.6140350877192983
# test_F1: 0.6619385342789598
# test_MCC: 0.4348131574778899
# test_roc_auc: 0.7121899576527526
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.6673106734931391
# val_Precision: 0.6406398886319469
# val_Recall: 0.5369774372073223
# val_F1: 0.5839869055845757
# test_ACC: 0.7258687258687259
# test_Precision: 0.7216494845360825
# test_Recall: 0.6140350877192983
# test_F1: 0.6635071090047394
# test_MCC: 0.4387957886912351
# test_roc_auc: 0.713914095583787
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.6673106734931391
# val_Precision: 0.6406398886319469
# val_Recall: 0.5369774372073223
# val_F1: 0.5839869055845757
# test_ACC: 0.7258687258687259
# test_Precision: 0.7216494845360825
# test_Recall: 0.6140350877192983
# test_F1: 0.6635071090047394
# test_MCC: 0.4387957886912351
# test_roc_auc: 0.713914095583787
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.6673106734931391
# val_Precision: 0.6406398886319469
# val_Recall: 0.5369774372073223
# val_F1: 0.5839869055845757
# test_ACC: 0.7258687258687259
# test_Precision: 0.7216494845360825
# test_Recall: 0.6140350877192983
# test_F1: 0.6635071090047394
# test_MCC: 0.4387957886912351
# test_roc_auc: 0.713914095583787
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 1.0, 140)
# val_ACC: 0.6673106734931391
# val_Precision: 0.6406398886319469
# val_Recall: 0.5369774372073223
# val_F1: 0.5839869055845757
# test_ACC: 0.7258687258687259
# test_Precision: 0.7216494845360825
# test_Recall: 0.6140350877192983
# test_F1: 0.6635071090047394
# test_MCC: 0.4387957886912351
# test_roc_auc: 0.713914095583787
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 1.0, 160)
# val_ACC: 0.6673106734931391
# val_Precision: 0.6406398886319469
# val_Recall: 0.5369774372073223
# val_F1: 0.5839869055845757
# test_ACC: 0.7258687258687259
# test_Precision: 0.7216494845360825
# test_Recall: 0.6140350877192983
# test_F1: 0.6635071090047394
# test_MCC: 0.4387957886912351
# test_roc_auc: 0.713914095583787
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 1.0, 150)
# val_ACC: 0.6673106734931391
# val_Precision: 0.6406398886319469
# val_Recall: 0.5369774372073223
# val_F1: 0.5839869055845757
# test_ACC: 0.7258687258687259
# test_Precision: 0.7216494845360825
# test_Recall: 0.6140350877192983
# test_F1: 0.6635071090047394
# test_MCC: 0.4387957886912351
# test_roc_auc: 0.713914095583787
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 1.0, 160)
# val_ACC: 0.6668787289145264
# val_Precision: 0.6392399643587923
# val_Recall: 0.5379565772669221
# val_F1: 0.5839725846175765
# test_ACC: 0.7258687258687259
# test_Precision: 0.7239583333333334
# test_Recall: 0.6096491228070176
# test_F1: 0.6619047619047619
# test_MCC: 0.43875643629528654
# test_roc_auc: 0.7134452510586812
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 4, 1, 1.0, 140)
# val_ACC: 0.6668787289145264
# val_Precision: 0.6392399643587923
# val_Recall: 0.5379565772669221
# val_F1: 0.5839725846175765
# test_ACC: 0.7258687258687259
# test_Precision: 0.7239583333333334
# test_Recall: 0.6096491228070176
# test_F1: 0.6619047619047619
# test_MCC: 0.43875643629528654
# test_roc_auc: 0.7134452510586812
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 1, 1.0, 160)
# val_ACC: 0.6666650566496004
# val_Precision: 0.6374261298060274
# val_Recall: 0.5423925074499787
# val_F1: 0.5859140442128447
# test_ACC: 0.7239382239382239
# test_Precision: 0.717948717948718
# test_Recall: 0.6140350877192983
# test_F1: 0.6619385342789598
# test_MCC: 0.4348131574778899
# test_roc_auc: 0.7121899576527526
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 0.9, 1.0, 150)
# val_ACC: 0.6666650566496004
# val_Precision: 0.6417180098895648
# val_Recall: 0.528590889740315
# val_F1: 0.5794769589926727
# test_ACC: 0.7432432432432432
# test_Precision: 0.7513227513227513
# test_Recall: 0.6228070175438597
# test_F1: 0.6810551558752997
# test_MCC: 0.4751072450928657
# test_roc_auc: 0.7303690260133092
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 0.9, 1.0, 150)
# val_ACC: 0.6666650566496004
# val_Precision: 0.6417180098895648
# val_Recall: 0.528590889740315
# val_F1: 0.5794769589926727
# test_ACC: 0.7432432432432432
# test_Precision: 0.7513227513227513
# test_Recall: 0.6228070175438597
# test_F1: 0.6810551558752997
# test_MCC: 0.4751072450928657
# test_roc_auc: 0.7303690260133092
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 6, 0.9, 1.0, 160)
# val_ACC: 0.6666650566496004
# val_Precision: 0.6417180098895648
# val_Recall: 0.528590889740315
# val_F1: 0.5794769589926727
# test_ACC: 0.7432432432432432
# test_Precision: 0.7513227513227513
# test_Recall: 0.6228070175438597
# test_F1: 0.6810551558752997
# test_MCC: 0.4751072450928657
# test_roc_auc: 0.7303690260133092
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.08, 5, 1, 0.8, 150)
# val_ACC: 0.6655934752908381
# val_Precision: 0.6407478600568136
# val_Recall: 0.5261241865839568
# val_F1: 0.5775886630195108
# test_ACC: 0.722007722007722
# test_Precision: 0.7079207920792079
# test_Recall: 0.6271929824561403
# test_F1: 0.6651162790697674
# test_MCC: 0.43127221811135347
# test_roc_auc: 0.7118723532970358
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 1.0, 160)
# val_ACC: 0.6627994056737002
# val_Precision: 0.6345623152183852
# val_Recall: 0.5295602992154718
# val_F1: 0.5770581080417145
# test_ACC: 0.7316602316602316
# test_Precision: 0.7305699481865285
# test_Recall: 0.618421052631579
# test_F1: 0.669833729216152
# test_MCC: 0.45083758532764256
# test_roc_auc: 0.7195553539019963
# ------------------------------------------------------------
# 超参数: learning_rate,depth,rsm,subsample,min_data_in_leaf : (0.1, 5, 0.9, 1.0, 150)
# val_ACC: 0.6627994056737002
# val_Precision: 0.6345623152183852
# val_Recall: 0.5295602992154718
# val_F1: 0.5770581080417145
# test_ACC: 0.7316602316602316
# test_Precision: 0.7305699481865285
# test_Recall: 0.618421052631579
# test_F1: 0.669833729216152
# test_MCC: 0.45083758532764256
# test_roc_auc: 0.7195553539019963
# ------------------------------------------------------------
